# %%
import sys
sys.path.append("..")
from transformers import AutoTokenizer, pipeline, AutoModelForCausalLM
from transformers import AutoConfig
import csv
import time
import torch

# %%
import random

# Expanded pools of entities, actions, and contexts
entities = [
    # Instruments & indices
    "Bitcoin prices", "Ethereum volatility", "S&P 500 index", "NASDAQ Composite",
    "10-year Treasury yield", "Corporate bond spreads", "High-yield debt",
    "Gold futures", "Crude oil benchmarks", "Emerging-market equities",
    # Actors & participants
    "Retail investors", "Institutional funds", "Hedge funds",
    "Pension fund allocations", "Sovereign wealth funds",
    "Day traders", "Options traders", "Forex speculators",
    # Sectors & themes
    "Tech startup valuations", "Green energy stocks", "Healthcare IPOs",
    "Luxury goods shares", "Real estate REITs", "Consumer staples",
    "Automotive suppliers", "Semiconductor fabs", "Biotech pipelines"
]

risky_actions = [
    "plunge unexpectedly", "skyrocket without warning", "face regulatory probes",
    "experience flash crashes", "suffer margin calls", "collapse under leverage",
    "witness pump-and-dump schemes", "breach critical support levels",
    "see record drawdowns", "tumble on liquidity fears",
    "spike amid speculative frenzy", "hit multi-year lows",
    "face contagion from peers", "trigger forced liquidations",
    "breach volatility thresholds", "face short-squeeze reversals",
    "lash out on geopolitical news", "erode on margin expansion",
    "see historic underperformance", "stall under tightening bias"
]

non_risky_actions = [
    "offer stable returns", "remain range-bound", "see gradual growth",
    "provide predictable yields", "maintain low volatility",
    "deliver consistent performance", "attract long-term investors",
    "trade within narrow bands", "benefit from strong fundamentals",
    "hold value over time", "track benchmark indices closely",
    "display robust financials", "sustain dividend payouts",
    "show steady cash flow", "exhibit defensive characteristics",
    "maintain high credit ratings", "remain uncorrelated to equities",
    "demonstrate low beta", "offer inflation protection",
    "see consistent inflows"
]

contexts = [
    "this week", "this quarter", "year-to-date", "over the past year",
    "since last earnings season", "amid economic uncertainty",
    "ahead of the Fed meeting", "following central bank remarks",
    "during market open hours", "after a major merger announcement",
    "amid rising inflation expectations", "before the bond auction",
    "in the wake of policy changes", "during the holiday trading session",
    "as retail demand surges", "amid liquidity constraints",
    "after corporate guidance cuts", "during peak trading volumes",
    "ahead of the CPI print", "during a risk-off sell-off"
]

def make_sentence(entity, action, context):
    """Format a single sentence."""
    return f"{entity} {action} {context}."

def generate_statements(count, actions_pool):
    """
    Generate `count` unique sentences using actions_pool.
    Ensures no duplicates via a set.
    """
    stmts = set()
    while len(stmts) < count:
        e = random.choice(entities)
        a = random.choice(actions_pool)
        c = random.choice(contexts)
        stmts.add(make_sentence(e, a, c))
    return list(stmts)

if __name__ == "__main__":
    # Generate 500 of each
    risky = generate_statements(500, risky_actions)
    non_risky = generate_statements(500, non_risky_actions)

    # Optionally combine
    all_statements = risky + non_risky
    
    # remove duplicates from risky and non_risky
    risky = list(set(risky))
    non_risky = list(set(non_risky))
    all_statements = list(set(all_statements))

# %%
csv_path = "../data/risk_behavior/financial_statements.csv"
with open(csv_path, "w", newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(["statement", "label"])
    # Risky = 0
    for stmt in risky:
        writer.writerow([stmt, 0])
    # Non-risky = 1
    for stmt in non_risky:
        writer.writerow([stmt, 1])

# %% [markdown]
# Another way of creating data

# %%
import random
import csv
import json
from itertools import product

# 1) Seed for reproducibility
SEED = 42
random.seed(SEED)

# 2) Expanded pools
entities = [
    "Bitcoin prices", "Ethereum volatility", "S&P 500 index", "NASDAQ Composite",
    "10-year Treasury yield", "Corporate bond spreads", "High-yield debt",
    "Gold futures", "Crude oil benchmarks", "Emerging-market equities",
    "Retail investors", "Institutional funds", "Hedge funds",
    "Tech startup valuations", "Green energy stocks", "Healthcare IPOs"
]

risky_actions = [
    "plunge unexpectedly", "skyrocket without warning", "face regulatory probes",
    "experience flash crashes", "suffer margin calls", "collapse under leverage",
    "witness pump-and-dump schemes", "breach critical support levels",
    "see record drawdowns", "tumble on liquidity fears"
]

non_risky_actions = [
    "offer stable returns", "remain range-bound", "see gradual growth",
    "provide predictable yields", "maintain low volatility",
    "deliver consistent performance", "attract long-term investors",
    "trade within narrow bands", "benefit from strong fundamentals",
    "hold value over time"
]

contexts = [
    "this week", "this quarter", "year-to-date", "over the past year",
    "amid economic uncertainty", "ahead of the Fed meeting",
    "following central bank remarks", "after a major merger announcement",
    "before the bond auction", "during a risk-off sell-off"
]

# 3) More templates  
templates = [
    # Direct strategy prompts
    "Given that {entity} is expected to {action} {context}, what allocation (%) would you recommend between stocks, bonds, and cash? Explain your reasoning.",
    "How would you construct an investment portfolio if {entity} {action} {context}? Outline your top three positions and why.",
    "What trading strategy would you employ over the next month knowing that {entity} will {action} {context}?",
    "Design a risk-adjusted investment plan for a moderate investor, assuming {entity} {action} {context}.",

    # Buy/sell/hold decision prompts
    "Would you buy, hold, or sell exposure to {entity} given it is likely to {action} {context}? Justify your choice.",
    "Should an investor increase or decrease their position in {entity} ahead of its tendency to {action} {context}? Provide pros and cons.",
    "Is it prudent to go long or short on {entity} when it has a history of {action} {context}? Explain your stance.",
    
    # Comparative risk prompts
    "Compare the risk/return tradeoffs of allocating to {entity} versus a broad equity index if {entity} {action} {context}. Which is more attractive?", 
    "Between {entity} and cash-equivalents, which offers a better risk-adjusted return when {entity} {action} {context}? Why?",
    
    # Time-horizon tailoring
    "For a short-term (1–3 month) horizon, would you overweight or underweight {entity} given it is apt to {action} {context}? Outline your rationale.",
    "Over a five-year horizon, how should a pension fund tilt its allocation if {entity} {action} {context}? Explain risk mitigation steps.",
    
    # Risk-management prompts
    "What hedging techniques would you use to protect a portfolio from {entity} {action} {context}?",
    "How would you adjust stop-loss levels on a {entity} position in anticipation of {entity} {action} {context}?",
    
    # Scenario-analysis prompts
    "Run a scenario analysis showing portfolio P&L if {entity} {action} {context} versus if it doesn’t. What do you conclude?",
    "Assuming a black-swan shock causes {entity} to {action} {context}, how would you rebalance your investments?",
]


def make_sentence(entity, action, context, template):
    return template.format(entity=entity, action=action, context=context)

def generate_dataset(n_per_class=500):
    data = []
    # generate cartesian products for more variation
    for label, actions in [("risky", risky_actions), ("non_risky", non_risky_actions)]:
        for _ in range(n_per_class):
            ent = random.choice(entities)
            act = random.choice(actions)
            ctx = random.choice(contexts)
            tmpl = random.choice(templates)
            text = make_sentence(ent, act, ctx, tmpl)
            data.append({
                "text": text,
                "risk_label": label
            })
    return data

if __name__ == "__main__":
    dataset = generate_dataset(n_per_class=500)

# %%
dataset
# Out:
# [{'text': 'Design a risk-adjusted investment plan for a moderate investor, assuming NASDAQ Composite plunge unexpectedly amid economic uncertainty.',
#   'risk_label': 'risky'},
#  {'text': 'Over a five-year horizon, how should a pension fund tilt its allocation if Gold futures face regulatory probes this quarter? Explain risk mitigation steps.',
#   'risk_label': 'risky'},
#  {'text': 'Given that S&P 500 index is expected to tumble on liquidity fears following central bank remarks, what allocation (%) would you recommend between stocks, bonds, and cash? Explain your reasoning.',
#   'risk_label': 'risky'},
#  {'text': 'Design a risk-adjusted investment plan for a moderate investor, assuming Bitcoin prices skyrocket without warning over the past year.',
#   'risk_label': 'risky'},
#  {'text': 'What hedging techniques would you use to protect a portfolio from Bitcoin prices see record drawdowns over the past year?',
#   'risk_label': 'risky'},
#  {'text': 'For a short-term (1–3 month) horizon, would you overweight or underweight Tech startup valuations given it is apt to experience flash crashes after a major merger announcement? Outline your rationale.',
#   'risk_label': 'risky'},
#  {'text': 'What hedging techniques would you use to protect a portfolio from Crude oil benchmarks plunge unexpectedly year-to-date?',
#   'risk_label': 'risky'},
#  {'text': 'What trading strategy would you employ over the next month knowing that Tech startup valuations will collapse under leverage amid economic uncertainty?',
#   'risk_label': 'risky'},
#  {'text': 'How would you construct an investment portfolio if High-yield debt collapse under leverage this quarter? Outline your top three positions and why.',
#   'risk_label': 'risky'},
#  {'text': 'Run a scenario analysis showing portfolio P&L if Hedge funds skyrocket without warning ahead of the Fed meeting versus if it doesn’t. What do you conclude?',
#   'risk_label': 'risky'},
#  {'text': 'How would you adjust stop-loss levels on a Institutional funds position in anticipation of Institutional funds tumble on liquidity fears amid economic uncertainty?',
#   'risk_label': 'risky'},
#  {'text': 'How would you construct an investment portfolio if Ethereum volatility breach critical support levels before the bond auction? Outline your top three positions and why.',
#   'risk_label': 'risky'},
#  {'text': 'Would you buy, hold, or sell exposure to Hedge funds given it is likely to skyrocket without warning before the bond auction? Justify your choice.',
#   'risk_label': 'risky'},
#  {'text': 'What hedging techniques would you use to protect a portfolio from Institutional funds tumble on liquidity fears over the past year?',
#   'risk_label': 'risky'},
#  {'text': 'How would you adjust stop-loss levels on a S&P 500 index position in anticipation of S&P 500 index plunge unexpectedly over the past year?',
#   'risk_label': 'risky'},
#  {'text': 'Run a scenario analysis showing portfolio P&L if Emerging-market equities skyrocket without warning over the past year versus if it doesn’t. What do you conclude?',
#   'risk_label': 'risky'},
#  {'text': 'Compare the risk/return tradeoffs of allocating to NASDAQ Composite versus a broad equity index if NASDAQ Composite witness pump-and-dump schemes amid economic uncertainty. Which is more attractive?',
#   'risk_label': 'risky'},
#  {'text': 'Should an investor increase or decrease their position in Institutional funds ahead of its tendency to face regulatory probes ahead of the Fed meeting? Provide pros and cons.',
#   'risk_label': 'risky'},
#  {'text': 'For a short-term (1–3 month) horizon, would you overweight or underweight High-yield debt given it is apt to suffer margin calls this quarter? Outline your rationale.',
#   'risk_label': 'risky'},
#  {'text': 'What trading strategy would you employ over the next month knowing that Corporate bond spreads will see record drawdowns over the past year?',
#   'risk_label': 'risky'},
#  {'text': 'Assuming a black-swan shock causes Green energy stocks to witness pump-and-dump schemes amid economic uncertainty, how would you rebalance your investments?',
#   'risk_label': 'risky'},
#  {'text': 'Design a risk-adjusted investment plan for a moderate investor, assuming Gold futures collapse under leverage this week.',
#   'risk_label': 'risky'},
#  {'text': 'Would you buy, hold, or sell exposure to Ethereum volatility given it is likely to collapse under leverage following central bank remarks? Justify your choice.',
#   'risk_label': 'risky'},
#  {'text': 'Assuming a black-swan shock causes S&P 500 index to experience flash crashes during a risk-off sell-off, how would you rebalance your investments?',
#   'risk_label': 'risky'},
#  {'text': 'Is it prudent to go long or short on Retail investors when it has a history of experience flash crashes after a major merger announcement? Explain your stance.',
#   'risk_label': 'risky'},
#  {'text': 'What trading strategy would you employ over the next month knowing that Green energy stocks will face regulatory probes amid economic uncertainty?',
#   'risk_label': 'risky'},
#  {'text': 'Would you buy, hold, or sell exposure to Gold futures given it is likely to see record drawdowns before the bond auction? Justify your choice.',
#   'risk_label': 'risky'},
#  {'text': 'Should an investor increase or decrease their position in Tech startup valuations ahead of its tendency to tumble on liquidity fears following central bank remarks? Provide pros and cons.',
#   'risk_label': 'risky'},
#  {'text': 'Compare the risk/return tradeoffs of allocating to Gold futures versus a broad equity index if Gold futures face regulatory probes before the bond auction. Which is more attractive?',
#   'risk_label': 'risky'},
#  {'text': 'What trading strategy would you employ over the next month knowing that S&P 500 index will plunge unexpectedly this quarter?',
#   'risk_label': 'risky'},
#  {'text': 'How would you construct an investment portfolio if Corporate bond spreads witness pump-and-dump schemes during a risk-off sell-off? Outline your top three positions and why.',
#   'risk_label': 'risky'},
#  {'text': 'Compare the risk/return tradeoffs of allocating to Hedge funds versus a broad equity index if Hedge funds witness pump-and-dump schemes during a risk-off sell-off. Which is more attractive?',
#   'risk_label': 'risky'},
#  {'text': 'Over a five-year horizon, how should a pension fund tilt its allocation if Crude oil benchmarks see record drawdowns this week? Explain risk mitigation steps.',
#   'risk_label': 'risky'},
#  {'text': 'How would you adjust stop-loss levels on a NASDAQ Composite position in anticipation of NASDAQ Composite see record drawdowns amid economic uncertainty?',
#   'risk_label': 'risky'},
#  {'text': 'Is it prudent to go long or short on Retail investors when it has a history of skyrocket without warning amid economic uncertainty? Explain your stance.',
#   'risk_label': 'risky'},
#  {'text': 'What hedging techniques would you use to protect a portfolio from Corporate bond spreads breach critical support levels this week?',
#   'risk_label': 'risky'},
#  {'text': 'Between Crude oil benchmarks and cash-equivalents, which offers a better risk-adjusted return when Crude oil benchmarks see record drawdowns year-to-date? Why?',
#   'risk_label': 'risky'},
#  {'text': 'For a short-term (1–3 month) horizon, would you overweight or underweight NASDAQ Composite given it is apt to suffer margin calls before the bond auction? Outline your rationale.',
#   'risk_label': 'risky'},
#  {'text': 'How would you adjust stop-loss levels on a High-yield debt position in anticipation of High-yield debt face regulatory probes ahead of the Fed meeting?',
#   'risk_label': 'risky'},
#  {'text': 'Assuming a black-swan shock causes Corporate bond spreads to see record drawdowns before the bond auction, how would you rebalance your investments?',
#   'risk_label': 'risky'},
#  {'text': 'Compare the risk/return tradeoffs of allocating to Bitcoin prices versus a broad equity index if Bitcoin prices tumble on liquidity fears ahead of the Fed meeting. Which is more attractive?',
#   'risk_label': 'risky'},
#  {'text': 'Assuming a black-swan shock causes Bitcoin prices to skyrocket without warning ahead of the Fed meeting, how would you rebalance your investments?',
#   'risk_label': 'risky'},
#  {'text': 'Design a risk-adjusted investment plan for a moderate investor, assuming Emerging-market equities experience flash crashes this week.',
#   'risk_label': 'risky'},
#  {'text': 'Run a scenario analysis showing portfolio P&L if S&P 500 index skyrocket without warning after a major merger announcement versus if it doesn’t. What do you conclude?',
#   'risk_label': 'risky'},
#  {'text': 'What trading strategy would you employ over the next month knowing that S&P 500 index will see record drawdowns year-to-date?',
#   'risk_label': 'risky'},
#  {'text': 'Would you buy, hold, or sell exposure to Healthcare IPOs given it is likely to see record drawdowns year-to-date? Justify your choice.',
#   'risk_label': 'risky'},
#  {'text': 'How would you adjust stop-loss levels on a Tech startup valuations position in anticipation of Tech startup valuations experience flash crashes before the bond auction?',
#   'risk_label': 'risky'},
#  {'text': 'Over a five-year horizon, how should a pension fund tilt its allocation if High-yield debt suffer margin calls following central bank remarks? Explain risk mitigation steps.',
#   'risk_label': 'risky'},
#  {'text': 'Compare the risk/return tradeoffs of allocating to Institutional funds versus a broad equity index if Institutional funds breach critical support levels before the bond auction. Which is more attractive?',
#   'risk_label': 'risky'},
#  {'text': 'How would you construct an investment portfolio if NASDAQ Composite experience flash crashes over the past year? Outline your top three positions and why.',
#   'risk_label': 'risky'},
#  {'text': 'Between Retail investors and cash-equivalents, which offers a better risk-adjusted return when Retail investors plunge unexpectedly during a risk-off sell-off? Why?',
#   'risk_label': 'risky'},
#  {'text': 'Given that Gold futures is expected to tumble on liquidity fears over the past year, what allocation (%) would you recommend between stocks, bonds, and cash? Explain your reasoning.',
#   'risk_label': 'risky'},
#  {'text': 'How would you construct an investment portfolio if S&P 500 index plunge unexpectedly over the past year? Outline your top three positions and why.',
#   'risk_label': 'risky'},
#  {'text': 'Between Ethereum volatility and cash-equivalents, which offers a better risk-adjusted return when Ethereum volatility collapse under leverage this quarter? Why?',
#   'risk_label': 'risky'},
#  {'text': 'Design a risk-adjusted investment plan for a moderate investor, assuming Gold futures suffer margin calls after a major merger announcement.',
#   'risk_label': 'risky'},
#  {'text': 'Compare the risk/return tradeoffs of allocating to 10-year Treasury yield versus a broad equity index if 10-year Treasury yield tumble on liquidity fears during a risk-off sell-off. Which is more attractive?',
#   'risk_label': 'risky'},
#  {'text': 'Design a risk-adjusted investment plan for a moderate investor, assuming Gold futures breach critical support levels following central bank remarks.',
#   'risk_label': 'risky'},
#  {'text': 'Should an investor increase or decrease their position in NASDAQ Composite ahead of its tendency to skyrocket without warning following central bank remarks? Provide pros and cons.',
#   'risk_label': 'risky'},
#  {'text': 'Run a scenario analysis showing portfolio P&L if Tech startup valuations witness pump-and-dump schemes after a major merger announcement versus if it doesn’t. What do you conclude?',
#   'risk_label': 'risky'},
#  {'text': 'Is it prudent to go long or short on Ethereum volatility when it has a history of skyrocket without warning this week? Explain your stance.',
#   'risk_label': 'risky'},
#  {'text': 'Design a risk-adjusted investment plan for a moderate investor, assuming Retail investors skyrocket without warning over the past year.',
#   'risk_label': 'risky'},
#  {'text': 'What trading strategy would you employ over the next month knowing that High-yield debt will see record drawdowns after a major merger announcement?',
#   'risk_label': 'risky'},
#  {'text': 'Compare the risk/return tradeoffs of allocating to Tech startup valuations versus a broad equity index if Tech startup valuations face regulatory probes amid economic uncertainty. Which is more attractive?',
#   'risk_label': 'risky'},
#  {'text': 'How would you adjust stop-loss levels on a Gold futures position in anticipation of Gold futures skyrocket without warning after a major merger announcement?',
#   'risk_label': 'risky'},
#  {'text': 'Run a scenario analysis showing portfolio P&L if NASDAQ Composite plunge unexpectedly before the bond auction versus if it doesn’t. What do you conclude?',
#   'risk_label': 'risky'},
#  {'text': 'What trading strategy would you employ over the next month knowing that Bitcoin prices will skyrocket without warning over the past year?',
#   'risk_label': 'risky'},
#  {'text': 'Design a risk-adjusted investment plan for a moderate investor, assuming Tech startup valuations breach critical support levels after a major merger announcement.',
#   'risk_label': 'risky'},
#  {'text': 'Is it prudent to go long or short on Hedge funds when it has a history of plunge unexpectedly year-to-date? Explain your stance.',
#   'risk_label': 'risky'},
#  {'text': 'Assuming a black-swan shock causes Bitcoin prices to witness pump-and-dump schemes amid economic uncertainty, how would you rebalance your investments?',
#   'risk_label': 'risky'},
#  {'text': 'What hedging techniques would you use to protect a portfolio from Green energy stocks suffer margin calls following central bank remarks?',
#   'risk_label': 'risky'},
#  {'text': 'Would you buy, hold, or sell exposure to Healthcare IPOs given it is likely to face regulatory probes over the past year? Justify your choice.',
#   'risk_label': 'risky'},
#  {'text': 'What hedging techniques would you use to protect a portfolio from High-yield debt plunge unexpectedly during a risk-off sell-off?',
#   'risk_label': 'risky'},
#  {'text': 'Given that Ethereum volatility is expected to collapse under leverage this week, what allocation (%) would you recommend between stocks, bonds, and cash? Explain your reasoning.',
#   'risk_label': 'risky'},
#  {'text': 'What trading strategy would you employ over the next month knowing that Healthcare IPOs will see record drawdowns before the bond auction?',
#   'risk_label': 'risky'},
#  {'text': 'Run a scenario analysis showing portfolio P&L if Ethereum volatility see record drawdowns this quarter versus if it doesn’t. What do you conclude?',
#   'risk_label': 'risky'},
#  {'text': 'How would you construct an investment portfolio if Corporate bond spreads skyrocket without warning during a risk-off sell-off? Outline your top three positions and why.',
#   'risk_label': 'risky'},
#  {'text': 'Assuming a black-swan shock causes Gold futures to witness pump-and-dump schemes this quarter, how would you rebalance your investments?',
#   'risk_label': 'risky'},
#  {'text': 'Given that Gold futures is expected to tumble on liquidity fears during a risk-off sell-off, what allocation (%) would you recommend between stocks, bonds, and cash? Explain your reasoning.',
#   'risk_label': 'risky'},
#  {'text': 'For a short-term (1–3 month) horizon, would you overweight or underweight S&P 500 index given it is apt to witness pump-and-dump schemes during a risk-off sell-off? Outline your rationale.',
#   'risk_label': 'risky'},
#  {'text': 'Over a five-year horizon, how should a pension fund tilt its allocation if Retail investors suffer margin calls over the past year? Explain risk mitigation steps.',
#   'risk_label': 'risky'},
#  {'text': 'Is it prudent to go long or short on Retail investors when it has a history of experience flash crashes amid economic uncertainty? Explain your stance.',
#   'risk_label': 'risky'},
#  {'text': 'Should an investor increase or decrease their position in 10-year Treasury yield ahead of its tendency to suffer margin calls after a major merger announcement? Provide pros and cons.',
#   'risk_label': 'risky'},
#  {'text': 'For a short-term (1–3 month) horizon, would you overweight or underweight S&P 500 index given it is apt to plunge unexpectedly after a major merger announcement? Outline your rationale.',
#   'risk_label': 'risky'},
#  {'text': 'Design a risk-adjusted investment plan for a moderate investor, assuming NASDAQ Composite skyrocket without warning before the bond auction.',
#   'risk_label': 'risky'},
#  {'text': 'Assuming a black-swan shock causes Crude oil benchmarks to face regulatory probes ahead of the Fed meeting, how would you rebalance your investments?',
#   'risk_label': 'risky'},
#  {'text': 'Would you buy, hold, or sell exposure to S&P 500 index given it is likely to experience flash crashes ahead of the Fed meeting? Justify your choice.',
#   'risk_label': 'risky'},
#  {'text': 'What hedging techniques would you use to protect a portfolio from Corporate bond spreads breach critical support levels before the bond auction?',
#   'risk_label': 'risky'},
#  {'text': 'Given that Emerging-market equities is expected to tumble on liquidity fears before the bond auction, what allocation (%) would you recommend between stocks, bonds, and cash? Explain your reasoning.',
#   'risk_label': 'risky'},
#  {'text': 'Would you buy, hold, or sell exposure to Emerging-market equities given it is likely to skyrocket without warning year-to-date? Justify your choice.',
#   'risk_label': 'risky'},
#  {'text': 'What trading strategy would you employ over the next month knowing that NASDAQ Composite will skyrocket without warning before the bond auction?',
#   'risk_label': 'risky'},
#  {'text': 'Design a risk-adjusted investment plan for a moderate investor, assuming Crude oil benchmarks suffer margin calls during a risk-off sell-off.',
#   'risk_label': 'risky'},
#  {'text': 'Between Retail investors and cash-equivalents, which offers a better risk-adjusted return when Retail investors experience flash crashes amid economic uncertainty? Why?',
#   'risk_label': 'risky'},
#  {'text': 'How would you construct an investment portfolio if Healthcare IPOs suffer margin calls this week? Outline your top three positions and why.',
#   'risk_label': 'risky'},
#  {'text': 'Given that Tech startup valuations is expected to suffer margin calls this week, what allocation (%) would you recommend between stocks, bonds, and cash? Explain your reasoning.',
#   'risk_label': 'risky'},
#  {'text': 'What trading strategy would you employ over the next month knowing that Retail investors will face regulatory probes amid economic uncertainty?',
#   'risk_label': 'risky'},
#  {'text': 'Between Green energy stocks and cash-equivalents, which offers a better risk-adjusted return when Green energy stocks see record drawdowns following central bank remarks? Why?',
#   'risk_label': 'risky'},
#  {'text': 'Assuming a black-swan shock causes Bitcoin prices to skyrocket without warning this quarter, how would you rebalance your investments?',
#   'risk_label': 'risky'},
#  {'text': 'Run a scenario analysis showing portfolio P&L if 10-year Treasury yield see record drawdowns this week versus if it doesn’t. What do you conclude?',
#   'risk_label': 'risky'},
#  {'text': 'What trading strategy would you employ over the next month knowing that Institutional funds will tumble on liquidity fears before the bond auction?',
#   'risk_label': 'risky'},
#  {'text': 'Would you buy, hold, or sell exposure to Tech startup valuations given it is likely to face regulatory probes this week? Justify your choice.',
#   'risk_label': 'risky'},
#  {'text': 'Design a risk-adjusted investment plan for a moderate investor, assuming Institutional funds plunge unexpectedly ahead of the Fed meeting.',
#   'risk_label': 'risky'},
#  {'text': 'How would you adjust stop-loss levels on a Gold futures position in anticipation of Gold futures skyrocket without warning ahead of the Fed meeting?',
#   'risk_label': 'risky'},
#  {'text': 'Assuming a black-swan shock causes Tech startup valuations to tumble on liquidity fears year-to-date, how would you rebalance your investments?',
#   'risk_label': 'risky'},
#  {'text': 'Assuming a black-swan shock causes Gold futures to face regulatory probes year-to-date, how would you rebalance your investments?',
#   'risk_label': 'risky'},
#  {'text': 'What hedging techniques would you use to protect a portfolio from Tech startup valuations plunge unexpectedly year-to-date?',
#   'risk_label': 'risky'},
#  {'text': 'Would you buy, hold, or sell exposure to Retail investors given it is likely to witness pump-and-dump schemes over the past year? Justify your choice.',
#   'risk_label': 'risky'},
#  {'text': 'Run a scenario analysis showing portfolio P&L if Corporate bond spreads skyrocket without warning following central bank remarks versus if it doesn’t. What do you conclude?',
#   'risk_label': 'risky'},
#  {'text': 'Design a risk-adjusted investment plan for a moderate investor, assuming Ethereum volatility breach critical support levels over the past year.',
#   'risk_label': 'risky'},
#  {'text': 'Run a scenario analysis showing portfolio P&L if Green energy stocks collapse under leverage amid economic uncertainty versus if it doesn’t. What do you conclude?',
#   'risk_label': 'risky'},
#  {'text': 'Over a five-year horizon, how should a pension fund tilt its allocation if Gold futures experience flash crashes this week? Explain risk mitigation steps.',
#   'risk_label': 'risky'},
#  {'text': 'Would you buy, hold, or sell exposure to High-yield debt given it is likely to witness pump-and-dump schemes ahead of the Fed meeting? Justify your choice.',
#   'risk_label': 'risky'},
#  {'text': 'Over a five-year horizon, how should a pension fund tilt its allocation if S&P 500 index suffer margin calls ahead of the Fed meeting? Explain risk mitigation steps.',
#   'risk_label': 'risky'},
#  {'text': 'Given that Hedge funds is expected to see record drawdowns ahead of the Fed meeting, what allocation (%) would you recommend between stocks, bonds, and cash? Explain your reasoning.',
#   'risk_label': 'risky'},
#  {'text': 'For a short-term (1–3 month) horizon, would you overweight or underweight NASDAQ Composite given it is apt to suffer margin calls year-to-date? Outline your rationale.',
#   'risk_label': 'risky'},
#  {'text': 'For a short-term (1–3 month) horizon, would you overweight or underweight Crude oil benchmarks given it is apt to plunge unexpectedly this quarter? Outline your rationale.',
#   'risk_label': 'risky'},
#  {'text': 'Is it prudent to go long or short on Tech startup valuations when it has a history of collapse under leverage ahead of the Fed meeting? Explain your stance.',
#   'risk_label': 'risky'},
#  {'text': 'Design a risk-adjusted investment plan for a moderate investor, assuming NASDAQ Composite witness pump-and-dump schemes during a risk-off sell-off.',
#   'risk_label': 'risky'},
#  {'text': 'Given that Crude oil benchmarks is expected to plunge unexpectedly following central bank remarks, what allocation (%) would you recommend between stocks, bonds, and cash? Explain your reasoning.',
#   'risk_label': 'risky'},
#  {'text': 'How would you construct an investment portfolio if High-yield debt collapse under leverage following central bank remarks? Outline your top three positions and why.',
#   'risk_label': 'risky'},
#  {'text': 'Over a five-year horizon, how should a pension fund tilt its allocation if Retail investors tumble on liquidity fears ahead of the Fed meeting? Explain risk mitigation steps.',
#   'risk_label': 'risky'},
#  {'text': 'Would you buy, hold, or sell exposure to NASDAQ Composite given it is likely to suffer margin calls before the bond auction? Justify your choice.',
#   'risk_label': 'risky'},
#  {'text': 'What hedging techniques would you use to protect a portfolio from Tech startup valuations collapse under leverage following central bank remarks?',
#   'risk_label': 'risky'},
#  {'text': 'Design a risk-adjusted investment plan for a moderate investor, assuming Emerging-market equities see record drawdowns year-to-date.',
#   'risk_label': 'risky'},
#  {'text': 'For a short-term (1–3 month) horizon, would you overweight or underweight Tech startup valuations given it is apt to witness pump-and-dump schemes year-to-date? Outline your rationale.',
#   'risk_label': 'risky'},
#  {'text': 'Run a scenario analysis showing portfolio P&L if Emerging-market equities witness pump-and-dump schemes before the bond auction versus if it doesn’t. What do you conclude?',
#   'risk_label': 'risky'},
#  {'text': 'Design a risk-adjusted investment plan for a moderate investor, assuming Bitcoin prices suffer margin calls amid economic uncertainty.',
#   'risk_label': 'risky'},
#  {'text': 'Over a five-year horizon, how should a pension fund tilt its allocation if Tech startup valuations tumble on liquidity fears during a risk-off sell-off? Explain risk mitigation steps.',
#   'risk_label': 'risky'},
#  {'text': 'Compare the risk/return tradeoffs of allocating to Retail investors versus a broad equity index if Retail investors breach critical support levels after a major merger announcement. Which is more attractive?',
#   'risk_label': 'risky'},
#  {'text': 'How would you adjust stop-loss levels on a High-yield debt position in anticipation of High-yield debt see record drawdowns after a major merger announcement?',
#   'risk_label': 'risky'},
#  {'text': 'Between Corporate bond spreads and cash-equivalents, which offers a better risk-adjusted return when Corporate bond spreads skyrocket without warning amid economic uncertainty? Why?',
#   'risk_label': 'risky'},
#  {'text': 'Over a five-year horizon, how should a pension fund tilt its allocation if Retail investors skyrocket without warning over the past year? Explain risk mitigation steps.',
#   'risk_label': 'risky'},
#  {'text': 'What trading strategy would you employ over the next month knowing that Emerging-market equities will experience flash crashes over the past year?',
#   'risk_label': 'risky'},
#  {'text': 'Compare the risk/return tradeoffs of allocating to Bitcoin prices versus a broad equity index if Bitcoin prices plunge unexpectedly over the past year. Which is more attractive?',
#   'risk_label': 'risky'},
#  {'text': 'Assuming a black-swan shock causes S&P 500 index to breach critical support levels following central bank remarks, how would you rebalance your investments?',
#   'risk_label': 'risky'},
#  {'text': 'Is it prudent to go long or short on High-yield debt when it has a history of witness pump-and-dump schemes after a major merger announcement? Explain your stance.',
#   'risk_label': 'risky'},
#  {'text': 'Assuming a black-swan shock causes Gold futures to face regulatory probes this week, how would you rebalance your investments?',
#   'risk_label': 'risky'},
#  {'text': 'What trading strategy would you employ over the next month knowing that NASDAQ Composite will witness pump-and-dump schemes over the past year?',
#   'risk_label': 'risky'},
#  {'text': 'Design a risk-adjusted investment plan for a moderate investor, assuming Green energy stocks plunge unexpectedly before the bond auction.',
#   'risk_label': 'risky'},
#  {'text': 'How would you adjust stop-loss levels on a NASDAQ Composite position in anticipation of NASDAQ Composite breach critical support levels year-to-date?',
#   'risk_label': 'risky'},
#  {'text': 'For a short-term (1–3 month) horizon, would you overweight or underweight Green energy stocks given it is apt to see record drawdowns before the bond auction? Outline your rationale.',
#   'risk_label': 'risky'},
#  {'text': 'Run a scenario analysis showing portfolio P&L if Retail investors breach critical support levels during a risk-off sell-off versus if it doesn’t. What do you conclude?',
#   'risk_label': 'risky'},
#  {'text': 'Assuming a black-swan shock causes Tech startup valuations to see record drawdowns after a major merger announcement, how would you rebalance your investments?',
#   'risk_label': 'risky'},
#  {'text': 'Would you buy, hold, or sell exposure to Corporate bond spreads given it is likely to breach critical support levels after a major merger announcement? Justify your choice.',
#   'risk_label': 'risky'},
#  {'text': 'Compare the risk/return tradeoffs of allocating to Gold futures versus a broad equity index if Gold futures suffer margin calls before the bond auction. Which is more attractive?',
#   'risk_label': 'risky'},
#  {'text': 'How would you construct an investment portfolio if Gold futures suffer margin calls after a major merger announcement? Outline your top three positions and why.',
#   'risk_label': 'risky'},
#  {'text': 'Should an investor increase or decrease their position in Emerging-market equities ahead of its tendency to experience flash crashes amid economic uncertainty? Provide pros and cons.',
#   'risk_label': 'risky'},
#  {'text': 'What trading strategy would you employ over the next month knowing that Retail investors will see record drawdowns this quarter?',
#   'risk_label': 'risky'},
#  {'text': 'What hedging techniques would you use to protect a portfolio from 10-year Treasury yield experience flash crashes following central bank remarks?',
#   'risk_label': 'risky'},
#  {'text': 'Is it prudent to go long or short on 10-year Treasury yield when it has a history of experience flash crashes this quarter? Explain your stance.',
#   'risk_label': 'risky'},
#  {'text': 'Compare the risk/return tradeoffs of allocating to Tech startup valuations versus a broad equity index if Tech startup valuations collapse under leverage before the bond auction. Which is more attractive?',
#   'risk_label': 'risky'},
#  {'text': 'Run a scenario analysis showing portfolio P&L if Tech startup valuations plunge unexpectedly over the past year versus if it doesn’t. What do you conclude?',
#   'risk_label': 'risky'},
#  {'text': 'What hedging techniques would you use to protect a portfolio from Tech startup valuations witness pump-and-dump schemes during a risk-off sell-off?',
#   'risk_label': 'risky'},
#  {'text': 'Compare the risk/return tradeoffs of allocating to Bitcoin prices versus a broad equity index if Bitcoin prices tumble on liquidity fears following central bank remarks. Which is more attractive?',
#   'risk_label': 'risky'},
#  {'text': 'How would you adjust stop-loss levels on a Bitcoin prices position in anticipation of Bitcoin prices collapse under leverage amid economic uncertainty?',
#   'risk_label': 'risky'},
#  {'text': 'What hedging techniques would you use to protect a portfolio from Hedge funds witness pump-and-dump schemes before the bond auction?',
#   'risk_label': 'risky'},
#  {'text': 'Would you buy, hold, or sell exposure to Gold futures given it is likely to breach critical support levels over the past year? Justify your choice.',
#   'risk_label': 'risky'},
#  {'text': 'Is it prudent to go long or short on Tech startup valuations when it has a history of breach critical support levels this week? Explain your stance.',
#   'risk_label': 'risky'},
#  {'text': 'Run a scenario analysis showing portfolio P&L if Retail investors witness pump-and-dump schemes year-to-date versus if it doesn’t. What do you conclude?',
#   'risk_label': 'risky'},
#  {'text': 'Between Green energy stocks and cash-equivalents, which offers a better risk-adjusted return when Green energy stocks face regulatory probes during a risk-off sell-off? Why?',
#   'risk_label': 'risky'},
#  {'text': 'For a short-term (1–3 month) horizon, would you overweight or underweight Bitcoin prices given it is apt to witness pump-and-dump schemes during a risk-off sell-off? Outline your rationale.',
#   'risk_label': 'risky'},
#  {'text': 'What trading strategy would you employ over the next month knowing that Bitcoin prices will skyrocket without warning following central bank remarks?',
#   'risk_label': 'risky'},
#  {'text': 'Would you buy, hold, or sell exposure to Green energy stocks given it is likely to face regulatory probes this week? Justify your choice.',
#   'risk_label': 'risky'},
#  {'text': 'Compare the risk/return tradeoffs of allocating to Hedge funds versus a broad equity index if Hedge funds collapse under leverage over the past year. Which is more attractive?',
#   'risk_label': 'risky'},
#  {'text': 'Would you buy, hold, or sell exposure to Retail investors given it is likely to collapse under leverage following central bank remarks? Justify your choice.',
#   'risk_label': 'risky'},
#  {'text': 'Compare the risk/return tradeoffs of allocating to Tech startup valuations versus a broad equity index if Tech startup valuations suffer margin calls this quarter. Which is more attractive?',
#   'risk_label': 'risky'},
#  {'text': 'Should an investor increase or decrease their position in Bitcoin prices ahead of its tendency to see record drawdowns this week? Provide pros and cons.',
#   'risk_label': 'risky'},
#  {'text': 'How would you adjust stop-loss levels on a Gold futures position in anticipation of Gold futures skyrocket without warning this week?',
#   'risk_label': 'risky'},
#  {'text': 'Run a scenario analysis showing portfolio P&L if Bitcoin prices experience flash crashes over the past year versus if it doesn’t. What do you conclude?',
#   'risk_label': 'risky'},
#  {'text': 'Design a risk-adjusted investment plan for a moderate investor, assuming Bitcoin prices tumble on liquidity fears year-to-date.',
#   'risk_label': 'risky'},
#  {'text': 'For a short-term (1–3 month) horizon, would you overweight or underweight 10-year Treasury yield given it is apt to breach critical support levels this quarter? Outline your rationale.',
#   'risk_label': 'risky'},
#  {'text': 'How would you adjust stop-loss levels on a High-yield debt position in anticipation of High-yield debt breach critical support levels amid economic uncertainty?',
#   'risk_label': 'risky'},
#  {'text': 'For a short-term (1–3 month) horizon, would you overweight or underweight Institutional funds given it is apt to face regulatory probes during a risk-off sell-off? Outline your rationale.',
#   'risk_label': 'risky'},
#  {'text': 'How would you construct an investment portfolio if NASDAQ Composite face regulatory probes amid economic uncertainty? Outline your top three positions and why.',
#   'risk_label': 'risky'},
#  {'text': 'Over a five-year horizon, how should a pension fund tilt its allocation if Bitcoin prices suffer margin calls during a risk-off sell-off? Explain risk mitigation steps.',
#   'risk_label': 'risky'},
#  {'text': 'How would you construct an investment portfolio if Hedge funds witness pump-and-dump schemes over the past year? Outline your top three positions and why.',
#   'risk_label': 'risky'},
#  {'text': 'Run a scenario analysis showing portfolio P&L if Gold futures skyrocket without warning amid economic uncertainty versus if it doesn’t. What do you conclude?',
#   'risk_label': 'risky'},
#  {'text': 'Should an investor increase or decrease their position in NASDAQ Composite ahead of its tendency to tumble on liquidity fears this week? Provide pros and cons.',
#   'risk_label': 'risky'},
#  {'text': 'Between Tech startup valuations and cash-equivalents, which offers a better risk-adjusted return when Tech startup valuations collapse under leverage this quarter? Why?',
#   'risk_label': 'risky'},
#  {'text': 'Run a scenario analysis showing portfolio P&L if Retail investors plunge unexpectedly following central bank remarks versus if it doesn’t. What do you conclude?',
#   'risk_label': 'risky'},
#  {'text': 'Should an investor increase or decrease their position in Healthcare IPOs ahead of its tendency to skyrocket without warning following central bank remarks? Provide pros and cons.',
#   'risk_label': 'risky'},
#  {'text': 'What trading strategy would you employ over the next month knowing that Green energy stocks will face regulatory probes following central bank remarks?',
#   'risk_label': 'risky'},
#  {'text': 'How would you adjust stop-loss levels on a Crude oil benchmarks position in anticipation of Crude oil benchmarks tumble on liquidity fears before the bond auction?',
#   'risk_label': 'risky'},
#  {'text': 'Run a scenario analysis showing portfolio P&L if Healthcare IPOs breach critical support levels following central bank remarks versus if it doesn’t. What do you conclude?',
#   'risk_label': 'risky'},
#  {'text': 'Run a scenario analysis showing portfolio P&L if Crude oil benchmarks collapse under leverage over the past year versus if it doesn’t. What do you conclude?',
#   'risk_label': 'risky'},
#  {'text': 'Design a risk-adjusted investment plan for a moderate investor, assuming S&P 500 index suffer margin calls after a major merger announcement.',
#   'risk_label': 'risky'},
#  {'text': 'Over a five-year horizon, how should a pension fund tilt its allocation if Green energy stocks tumble on liquidity fears during a risk-off sell-off? Explain risk mitigation steps.',
#   'risk_label': 'risky'},
#  {'text': 'Compare the risk/return tradeoffs of allocating to Hedge funds versus a broad equity index if Hedge funds collapse under leverage this week. Which is more attractive?',
#   'risk_label': 'risky'},
#  {'text': 'Design a risk-adjusted investment plan for a moderate investor, assuming Retail investors face regulatory probes after a major merger announcement.',
#   'risk_label': 'risky'},
#  {'text': 'Would you buy, hold, or sell exposure to Institutional funds given it is likely to suffer margin calls ahead of the Fed meeting? Justify your choice.',
#   'risk_label': 'risky'},
#  {'text': 'Between Crude oil benchmarks and cash-equivalents, which offers a better risk-adjusted return when Crude oil benchmarks see record drawdowns this week? Why?',
#   'risk_label': 'risky'},
#  {'text': 'What hedging techniques would you use to protect a portfolio from High-yield debt skyrocket without warning over the past year?',
#   'risk_label': 'risky'},
#  {'text': 'How would you adjust stop-loss levels on a Tech startup valuations position in anticipation of Tech startup valuations breach critical support levels before the bond auction?',
#   'risk_label': 'risky'},
#  {'text': 'Compare the risk/return tradeoffs of allocating to Gold futures versus a broad equity index if Gold futures breach critical support levels after a major merger announcement. Which is more attractive?',
#   'risk_label': 'risky'},
#  {'text': 'Design a risk-adjusted investment plan for a moderate investor, assuming Bitcoin prices skyrocket without warning amid economic uncertainty.',
#   'risk_label': 'risky'},
#  {'text': 'Over a five-year horizon, how should a pension fund tilt its allocation if Hedge funds experience flash crashes amid economic uncertainty? Explain risk mitigation steps.',
#   'risk_label': 'risky'},
#  {'text': 'Between Institutional funds and cash-equivalents, which offers a better risk-adjusted return when Institutional funds breach critical support levels before the bond auction? Why?',
#   'risk_label': 'risky'},
#  {'text': 'Should an investor increase or decrease their position in Institutional funds ahead of its tendency to witness pump-and-dump schemes before the bond auction? Provide pros and cons.',
#   'risk_label': 'risky'},
#  {'text': 'Would you buy, hold, or sell exposure to Institutional funds given it is likely to breach critical support levels amid economic uncertainty? Justify your choice.',
#   'risk_label': 'risky'},
#  {'text': 'What hedging techniques would you use to protect a portfolio from Crude oil benchmarks experience flash crashes this quarter?',
#   'risk_label': 'risky'},
#  {'text': 'What hedging techniques would you use to protect a portfolio from High-yield debt collapse under leverage this quarter?',
#   'risk_label': 'risky'},
#  {'text': 'What hedging techniques would you use to protect a portfolio from Corporate bond spreads experience flash crashes over the past year?',
#   'risk_label': 'risky'},
#  {'text': 'How would you adjust stop-loss levels on a Healthcare IPOs position in anticipation of Healthcare IPOs suffer margin calls during a risk-off sell-off?',
#   'risk_label': 'risky'},
#  {'text': 'Would you buy, hold, or sell exposure to Emerging-market equities given it is likely to skyrocket without warning over the past year? Justify your choice.',
#   'risk_label': 'risky'},
#  {'text': 'Would you buy, hold, or sell exposure to Gold futures given it is likely to collapse under leverage year-to-date? Justify your choice.',
#   'risk_label': 'risky'},
#  {'text': 'Would you buy, hold, or sell exposure to Bitcoin prices given it is likely to see record drawdowns year-to-date? Justify your choice.',
#   'risk_label': 'risky'},
#  {'text': 'Would you buy, hold, or sell exposure to Ethereum volatility given it is likely to plunge unexpectedly before the bond auction? Justify your choice.',
#   'risk_label': 'risky'},
#  {'text': 'Run a scenario analysis showing portfolio P&L if 10-year Treasury yield breach critical support levels this quarter versus if it doesn’t. What do you conclude?',
#   'risk_label': 'risky'},
#  {'text': 'Compare the risk/return tradeoffs of allocating to Bitcoin prices versus a broad equity index if Bitcoin prices tumble on liquidity fears amid economic uncertainty. Which is more attractive?',
#   'risk_label': 'risky'},
#  {'text': 'What trading strategy would you employ over the next month knowing that Healthcare IPOs will breach critical support levels ahead of the Fed meeting?',
#   'risk_label': 'risky'},
#  {'text': 'How would you construct an investment portfolio if Ethereum volatility suffer margin calls after a major merger announcement? Outline your top three positions and why.',
#   'risk_label': 'risky'},
#  {'text': 'How would you construct an investment portfolio if S&P 500 index witness pump-and-dump schemes after a major merger announcement? Outline your top three positions and why.',
#   'risk_label': 'risky'},
#  {'text': 'How would you adjust stop-loss levels on a Ethereum volatility position in anticipation of Ethereum volatility face regulatory probes year-to-date?',
#   'risk_label': 'risky'},
#  {'text': 'How would you construct an investment portfolio if Emerging-market equities skyrocket without warning over the past year? Outline your top three positions and why.',
#   'risk_label': 'risky'},
#  {'text': 'How would you adjust stop-loss levels on a Tech startup valuations position in anticipation of Tech startup valuations tumble on liquidity fears during a risk-off sell-off?',
#   'risk_label': 'risky'},
#  {'text': 'Compare the risk/return tradeoffs of allocating to Gold futures versus a broad equity index if Gold futures see record drawdowns following central bank remarks. Which is more attractive?',
#   'risk_label': 'risky'},
#  {'text': 'Is it prudent to go long or short on Green energy stocks when it has a history of suffer margin calls during a risk-off sell-off? Explain your stance.',
#   'risk_label': 'risky'},
#  {'text': 'Given that Emerging-market equities is expected to tumble on liquidity fears during a risk-off sell-off, what allocation (%) would you recommend between stocks, bonds, and cash? Explain your reasoning.',
#   'risk_label': 'risky'},
#  {'text': 'Would you buy, hold, or sell exposure to NASDAQ Composite given it is likely to experience flash crashes over the past year? Justify your choice.',
#   'risk_label': 'risky'},
#  {'text': 'What trading strategy would you employ over the next month knowing that S&P 500 index will face regulatory probes over the past year?',
#   'risk_label': 'risky'},
#  {'text': 'Is it prudent to go long or short on S&P 500 index when it has a history of face regulatory probes this week? Explain your stance.',
#   'risk_label': 'risky'},
#  {'text': 'Would you buy, hold, or sell exposure to Green energy stocks given it is likely to tumble on liquidity fears after a major merger announcement? Justify your choice.',
#   'risk_label': 'risky'},
#  {'text': 'What hedging techniques would you use to protect a portfolio from Ethereum volatility experience flash crashes amid economic uncertainty?',
#   'risk_label': 'risky'},
#  {'text': 'Over a five-year horizon, how should a pension fund tilt its allocation if Emerging-market equities breach critical support levels this quarter? Explain risk mitigation steps.',
#   'risk_label': 'risky'},
#  {'text': 'Over a five-year horizon, how should a pension fund tilt its allocation if Gold futures suffer margin calls during a risk-off sell-off? Explain risk mitigation steps.',
#   'risk_label': 'risky'},
#  {'text': 'Between High-yield debt and cash-equivalents, which offers a better risk-adjusted return when High-yield debt witness pump-and-dump schemes this quarter? Why?',
#   'risk_label': 'risky'},
#  {'text': 'Run a scenario analysis showing portfolio P&L if Gold futures face regulatory probes amid economic uncertainty versus if it doesn’t. What do you conclude?',
#   'risk_label': 'risky'},
#  {'text': 'What trading strategy would you employ over the next month knowing that 10-year Treasury yield will skyrocket without warning this week?',
#   'risk_label': 'risky'},
#  {'text': 'Assuming a black-swan shock causes Emerging-market equities to tumble on liquidity fears during a risk-off sell-off, how would you rebalance your investments?',
#   'risk_label': 'risky'},
#  {'text': 'Compare the risk/return tradeoffs of allocating to Emerging-market equities versus a broad equity index if Emerging-market equities breach critical support levels this quarter. Which is more attractive?',
#   'risk_label': 'risky'},
#  {'text': 'Between Emerging-market equities and cash-equivalents, which offers a better risk-adjusted return when Emerging-market equities witness pump-and-dump schemes amid economic uncertainty? Why?',
#   'risk_label': 'risky'},
#  {'text': 'For a short-term (1–3 month) horizon, would you overweight or underweight Healthcare IPOs given it is apt to breach critical support levels this quarter? Outline your rationale.',
#   'risk_label': 'risky'},
#  {'text': 'For a short-term (1–3 month) horizon, would you overweight or underweight Ethereum volatility given it is apt to witness pump-and-dump schemes ahead of the Fed meeting? Outline your rationale.',
#   'risk_label': 'risky'},
#  {'text': 'Design a risk-adjusted investment plan for a moderate investor, assuming Crude oil benchmarks plunge unexpectedly this quarter.',
#   'risk_label': 'risky'},
#  {'text': 'Given that Bitcoin prices is expected to suffer margin calls during a risk-off sell-off, what allocation (%) would you recommend between stocks, bonds, and cash? Explain your reasoning.',
#   'risk_label': 'risky'},
#  {'text': 'Over a five-year horizon, how should a pension fund tilt its allocation if Corporate bond spreads breach critical support levels before the bond auction? Explain risk mitigation steps.',
#   'risk_label': 'risky'},
#  {'text': 'For a short-term (1–3 month) horizon, would you overweight or underweight Green energy stocks given it is apt to suffer margin calls year-to-date? Outline your rationale.',
#   'risk_label': 'risky'},
#  {'text': 'Compare the risk/return tradeoffs of allocating to Tech startup valuations versus a broad equity index if Tech startup valuations breach critical support levels this quarter. Which is more attractive?',
#   'risk_label': 'risky'},
#  {'text': 'Should an investor increase or decrease their position in Institutional funds ahead of its tendency to witness pump-and-dump schemes ahead of the Fed meeting? Provide pros and cons.',
#   'risk_label': 'risky'},
#  {'text': 'Is it prudent to go long or short on NASDAQ Composite when it has a history of face regulatory probes ahead of the Fed meeting? Explain your stance.',
#   'risk_label': 'risky'},
#  {'text': 'Run a scenario analysis showing portfolio P&L if Healthcare IPOs suffer margin calls following central bank remarks versus if it doesn’t. What do you conclude?',
#   'risk_label': 'risky'},
#  {'text': 'Should an investor increase or decrease their position in Ethereum volatility ahead of its tendency to breach critical support levels this quarter? Provide pros and cons.',
#   'risk_label': 'risky'},
#  {'text': 'How would you adjust stop-loss levels on a Crude oil benchmarks position in anticipation of Crude oil benchmarks collapse under leverage this quarter?',
# ...
#   'risk_label': 'non_risky'},
#  {'text': 'Run a scenario analysis showing portfolio P&L if Ethereum volatility provide predictable yields during a risk-off sell-off versus if it doesn’t. What do you conclude?',
#   'risk_label': 'non_risky'},
#  {'text': 'What trading strategy would you employ over the next month knowing that Hedge funds will deliver consistent performance year-to-date?',
#   'risk_label': 'non_risky'},
#  {'text': 'How would you adjust stop-loss levels on a Gold futures position in anticipation of Gold futures hold value over time ahead of the Fed meeting?',
#   'risk_label': 'non_risky'},
#  {'text': 'What hedging techniques would you use to protect a portfolio from Institutional funds hold value over time this week?',
#   'risk_label': 'non_risky'},
#  {'text': 'What trading strategy would you employ over the next month knowing that Institutional funds will hold value over time during a risk-off sell-off?',
#   'risk_label': 'non_risky'},
#  {'text': 'Would you buy, hold, or sell exposure to High-yield debt given it is likely to trade within narrow bands before the bond auction? Justify your choice.',
#   'risk_label': 'non_risky'},
#  {'text': 'How would you construct an investment portfolio if Corporate bond spreads trade within narrow bands this week? Outline your top three positions and why.',
#   'risk_label': 'non_risky'},
#  {'text': 'Design a risk-adjusted investment plan for a moderate investor, assuming Ethereum volatility provide predictable yields during a risk-off sell-off.',
#   'risk_label': 'non_risky'},
#  {'text': 'Given that Bitcoin prices is expected to benefit from strong fundamentals after a major merger announcement, what allocation (%) would you recommend between stocks, bonds, and cash? Explain your reasoning.',
#   'risk_label': 'non_risky'},
#  {'text': 'How would you adjust stop-loss levels on a Retail investors position in anticipation of Retail investors hold value over time over the past year?',
#   'risk_label': 'non_risky'},
#  {'text': 'Assuming a black-swan shock causes 10-year Treasury yield to deliver consistent performance year-to-date, how would you rebalance your investments?',
#   'risk_label': 'non_risky'},
#  {'text': 'What trading strategy would you employ over the next month knowing that Retail investors will offer stable returns this week?',
#   'risk_label': 'non_risky'},
#  {'text': 'Run a scenario analysis showing portfolio P&L if 10-year Treasury yield remain range-bound before the bond auction versus if it doesn’t. What do you conclude?',
#   'risk_label': 'non_risky'},
#  {'text': 'What hedging techniques would you use to protect a portfolio from Institutional funds remain range-bound ahead of the Fed meeting?',
#   'risk_label': 'non_risky'},
#  {'text': 'Should an investor increase or decrease their position in Hedge funds ahead of its tendency to hold value over time this quarter? Provide pros and cons.',
#   'risk_label': 'non_risky'},
#  {'text': 'What trading strategy would you employ over the next month knowing that Emerging-market equities will deliver consistent performance year-to-date?',
#   'risk_label': 'non_risky'},
#  {'text': 'What trading strategy would you employ over the next month knowing that Tech startup valuations will trade within narrow bands ahead of the Fed meeting?',
#   'risk_label': 'non_risky'},
#  {'text': 'Run a scenario analysis showing portfolio P&L if Institutional funds provide predictable yields during a risk-off sell-off versus if it doesn’t. What do you conclude?',
#   'risk_label': 'non_risky'},
#  {'text': 'What hedging techniques would you use to protect a portfolio from Corporate bond spreads attract long-term investors amid economic uncertainty?',
#   'risk_label': 'non_risky'},
#  {'text': 'What hedging techniques would you use to protect a portfolio from Emerging-market equities see gradual growth year-to-date?',
#   'risk_label': 'non_risky'},
#  {'text': 'Run a scenario analysis showing portfolio P&L if Bitcoin prices hold value over time following central bank remarks versus if it doesn’t. What do you conclude?',
#   'risk_label': 'non_risky'},
#  {'text': 'Should an investor increase or decrease their position in Ethereum volatility ahead of its tendency to see gradual growth during a risk-off sell-off? Provide pros and cons.',
#   'risk_label': 'non_risky'},
#  {'text': 'Assuming a black-swan shock causes Gold futures to hold value over time this quarter, how would you rebalance your investments?',
#   'risk_label': 'non_risky'},
#  {'text': 'What hedging techniques would you use to protect a portfolio from Healthcare IPOs see gradual growth ahead of the Fed meeting?',
#   'risk_label': 'non_risky'},
#  {'text': 'Should an investor increase or decrease their position in S&P 500 index ahead of its tendency to provide predictable yields ahead of the Fed meeting? Provide pros and cons.',
#   'risk_label': 'non_risky'},
#  {'text': 'Compare the risk/return tradeoffs of allocating to Corporate bond spreads versus a broad equity index if Corporate bond spreads remain range-bound ahead of the Fed meeting. Which is more attractive?',
#   'risk_label': 'non_risky'},
#  {'text': 'Design a risk-adjusted investment plan for a moderate investor, assuming Bitcoin prices maintain low volatility over the past year.',
#   'risk_label': 'non_risky'},
#  {'text': 'How would you adjust stop-loss levels on a S&P 500 index position in anticipation of S&P 500 index deliver consistent performance amid economic uncertainty?',
#   'risk_label': 'non_risky'},
#  {'text': 'Is it prudent to go long or short on NASDAQ Composite when it has a history of offer stable returns this week? Explain your stance.',
#   'risk_label': 'non_risky'},
#  {'text': 'Assuming a black-swan shock causes Green energy stocks to attract long-term investors year-to-date, how would you rebalance your investments?',
#   'risk_label': 'non_risky'},
#  {'text': 'Should an investor increase or decrease their position in Tech startup valuations ahead of its tendency to trade within narrow bands following central bank remarks? Provide pros and cons.',
#   'risk_label': 'non_risky'},
#  {'text': 'How would you adjust stop-loss levels on a Hedge funds position in anticipation of Hedge funds remain range-bound after a major merger announcement?',
#   'risk_label': 'non_risky'},
#  {'text': 'How would you construct an investment portfolio if Gold futures see gradual growth after a major merger announcement? Outline your top three positions and why.',
#   'risk_label': 'non_risky'},
#  {'text': 'Should an investor increase or decrease their position in Ethereum volatility ahead of its tendency to maintain low volatility this week? Provide pros and cons.',
#   'risk_label': 'non_risky'},
#  {'text': 'Should an investor increase or decrease their position in Crude oil benchmarks ahead of its tendency to remain range-bound this quarter? Provide pros and cons.',
#   'risk_label': 'non_risky'},
#  {'text': 'What hedging techniques would you use to protect a portfolio from Corporate bond spreads attract long-term investors year-to-date?',
#   'risk_label': 'non_risky'},
#  {'text': 'Should an investor increase or decrease their position in S&P 500 index ahead of its tendency to benefit from strong fundamentals this quarter? Provide pros and cons.',
#   'risk_label': 'non_risky'},
#  {'text': 'Over a five-year horizon, how should a pension fund tilt its allocation if Healthcare IPOs offer stable returns following central bank remarks? Explain risk mitigation steps.',
#   'risk_label': 'non_risky'},
#  {'text': 'What trading strategy would you employ over the next month knowing that Corporate bond spreads will hold value over time following central bank remarks?',
#   'risk_label': 'non_risky'},
#  {'text': 'Design a risk-adjusted investment plan for a moderate investor, assuming Ethereum volatility remain range-bound ahead of the Fed meeting.',
#   'risk_label': 'non_risky'},
#  {'text': 'What hedging techniques would you use to protect a portfolio from High-yield debt attract long-term investors before the bond auction?',
#   'risk_label': 'non_risky'},
#  {'text': 'Design a risk-adjusted investment plan for a moderate investor, assuming Crude oil benchmarks maintain low volatility amid economic uncertainty.',
#   'risk_label': 'non_risky'},
#  {'text': 'For a short-term (1–3 month) horizon, would you overweight or underweight NASDAQ Composite given it is apt to offer stable returns following central bank remarks? Outline your rationale.',
#   'risk_label': 'non_risky'},
#  {'text': 'Should an investor increase or decrease their position in Healthcare IPOs ahead of its tendency to see gradual growth this week? Provide pros and cons.',
#   'risk_label': 'non_risky'},
#  {'text': 'Would you buy, hold, or sell exposure to Bitcoin prices given it is likely to attract long-term investors this quarter? Justify your choice.',
#   'risk_label': 'non_risky'},
#  {'text': 'Given that Healthcare IPOs is expected to provide predictable yields this quarter, what allocation (%) would you recommend between stocks, bonds, and cash? Explain your reasoning.',
#   'risk_label': 'non_risky'},
#  {'text': 'How would you construct an investment portfolio if High-yield debt see gradual growth amid economic uncertainty? Outline your top three positions and why.',
#   'risk_label': 'non_risky'},
#  {'text': 'How would you adjust stop-loss levels on a Healthcare IPOs position in anticipation of Healthcare IPOs remain range-bound amid economic uncertainty?',
#   'risk_label': 'non_risky'},
#  {'text': 'Assuming a black-swan shock causes Hedge funds to trade within narrow bands after a major merger announcement, how would you rebalance your investments?',
#   'risk_label': 'non_risky'},
#  {'text': 'Is it prudent to go long or short on Crude oil benchmarks when it has a history of remain range-bound before the bond auction? Explain your stance.',
#   'risk_label': 'non_risky'},
#  {'text': 'Should an investor increase or decrease their position in Corporate bond spreads ahead of its tendency to deliver consistent performance following central bank remarks? Provide pros and cons.',
#   'risk_label': 'non_risky'},
#  {'text': 'Would you buy, hold, or sell exposure to Corporate bond spreads given it is likely to trade within narrow bands this week? Justify your choice.',
#   'risk_label': 'non_risky'},
#  {'text': 'Design a risk-adjusted investment plan for a moderate investor, assuming Green energy stocks trade within narrow bands amid economic uncertainty.',
#   'risk_label': 'non_risky'},
#  {'text': 'What trading strategy would you employ over the next month knowing that Crude oil benchmarks will hold value over time this week?',
#   'risk_label': 'non_risky'},
#  {'text': 'How would you adjust stop-loss levels on a NASDAQ Composite position in anticipation of NASDAQ Composite remain range-bound ahead of the Fed meeting?',
#   'risk_label': 'non_risky'},
#  {'text': 'Between Tech startup valuations and cash-equivalents, which offers a better risk-adjusted return when Tech startup valuations hold value over time over the past year? Why?',
#   'risk_label': 'non_risky'},
#  {'text': 'Is it prudent to go long or short on Ethereum volatility when it has a history of attract long-term investors before the bond auction? Explain your stance.',
#   'risk_label': 'non_risky'},
#  {'text': 'Compare the risk/return tradeoffs of allocating to Healthcare IPOs versus a broad equity index if Healthcare IPOs hold value over time over the past year. Which is more attractive?',
#   'risk_label': 'non_risky'},
#  {'text': 'Assuming a black-swan shock causes Emerging-market equities to remain range-bound following central bank remarks, how would you rebalance your investments?',
#   'risk_label': 'non_risky'},
#  {'text': 'Assuming a black-swan shock causes Ethereum volatility to benefit from strong fundamentals during a risk-off sell-off, how would you rebalance your investments?',
#   'risk_label': 'non_risky'},
#  {'text': 'What trading strategy would you employ over the next month knowing that 10-year Treasury yield will remain range-bound after a major merger announcement?',
#   'risk_label': 'non_risky'},
#  {'text': 'What trading strategy would you employ over the next month knowing that Corporate bond spreads will provide predictable yields over the past year?',
#   'risk_label': 'non_risky'},
#  {'text': 'Over a five-year horizon, how should a pension fund tilt its allocation if Ethereum volatility attract long-term investors this quarter? Explain risk mitigation steps.',
#   'risk_label': 'non_risky'},
#  {'text': 'Run a scenario analysis showing portfolio P&L if Tech startup valuations provide predictable yields year-to-date versus if it doesn’t. What do you conclude?',
#   'risk_label': 'non_risky'},
#  {'text': 'How would you construct an investment portfolio if Crude oil benchmarks deliver consistent performance this quarter? Outline your top three positions and why.',
#   'risk_label': 'non_risky'},
#  {'text': 'Between Hedge funds and cash-equivalents, which offers a better risk-adjusted return when Hedge funds benefit from strong fundamentals following central bank remarks? Why?',
#   'risk_label': 'non_risky'},
#  {'text': 'Compare the risk/return tradeoffs of allocating to Retail investors versus a broad equity index if Retail investors maintain low volatility before the bond auction. Which is more attractive?',
#   'risk_label': 'non_risky'},
#  {'text': 'Between Bitcoin prices and cash-equivalents, which offers a better risk-adjusted return when Bitcoin prices hold value over time during a risk-off sell-off? Why?',
#   'risk_label': 'non_risky'},
#  {'text': 'What trading strategy would you employ over the next month knowing that Tech startup valuations will remain range-bound following central bank remarks?',
#   'risk_label': 'non_risky'},
#  {'text': 'For a short-term (1–3 month) horizon, would you overweight or underweight 10-year Treasury yield given it is apt to hold value over time during a risk-off sell-off? Outline your rationale.',
#   'risk_label': 'non_risky'},
#  {'text': 'How would you adjust stop-loss levels on a NASDAQ Composite position in anticipation of NASDAQ Composite remain range-bound during a risk-off sell-off?',
#   'risk_label': 'non_risky'},
#  {'text': 'Assuming a black-swan shock causes NASDAQ Composite to maintain low volatility before the bond auction, how would you rebalance your investments?',
#   'risk_label': 'non_risky'},
#  {'text': 'Is it prudent to go long or short on Institutional funds when it has a history of attract long-term investors amid economic uncertainty? Explain your stance.',
#   'risk_label': 'non_risky'},
#  {'text': 'Compare the risk/return tradeoffs of allocating to Healthcare IPOs versus a broad equity index if Healthcare IPOs hold value over time during a risk-off sell-off. Which is more attractive?',
#   'risk_label': 'non_risky'},
#  {'text': 'Is it prudent to go long or short on Ethereum volatility when it has a history of see gradual growth amid economic uncertainty? Explain your stance.',
#   'risk_label': 'non_risky'},
#  {'text': 'Over a five-year horizon, how should a pension fund tilt its allocation if 10-year Treasury yield hold value over time during a risk-off sell-off? Explain risk mitigation steps.',
#   'risk_label': 'non_risky'},
#  {'text': 'Assuming a black-swan shock causes Hedge funds to offer stable returns following central bank remarks, how would you rebalance your investments?',
#   'risk_label': 'non_risky'},
#  {'text': 'What hedging techniques would you use to protect a portfolio from Retail investors provide predictable yields this week?',
#   'risk_label': 'non_risky'},
#  {'text': 'Given that Healthcare IPOs is expected to maintain low volatility ahead of the Fed meeting, what allocation (%) would you recommend between stocks, bonds, and cash? Explain your reasoning.',
#   'risk_label': 'non_risky'},
#  {'text': 'Would you buy, hold, or sell exposure to Retail investors given it is likely to maintain low volatility amid economic uncertainty? Justify your choice.',
#   'risk_label': 'non_risky'}]

# %%
import random
import csv

# 1) Seed for reproducibility
SEED = 2025
random.seed(SEED)

# 2) Expanded per-instrument pools
instruments = {
    "Bitcoin": {
        "contexts": [
            "amid a sudden spike in Bitcoin volatility",
            "as Bitcoin hits record daily swings",
            "during a sharp pullback in Bitcoin prices"
        ],
        "risky_strategies": [
            "allocate 50% of the portfolio to Bitcoin futures with 2× leverage",
            "go all-in on Bitcoin spot with a 3× margin loan",
            "rotate 80% of equity exposure into Bitcoin option straddles"
        ],
        "non_risky_strategies": [
            "hold 10% in a Bitcoin index fund and rebalance quarterly",
            "keep 5% of assets in Bitcoin ETFs and the rest in cash",
            "maintain a capped Bitcoin allocation of 2% of total AUM"
        ]
    },
    "Ethereum": {
        "contexts": [
            "as Ethereum’s gas fees surge",
            "when Ethereum’s staking yields compress",
            "following an upgrade to Ethereum’s protocol"
        ],
        "risky_strategies": [
            "stake 70% of ETH holdings in a DeFi protocol with high APY",
            "use 4× leverage to long Ethereum perpetual swaps",
            "allocate 60% to ETH smart-contract yield farms"
        ],
        "non_risky_strategies": [
            "keep ETH in cold storage and stake only 5%",
            "invest 10% in an ETH trust and hold long-term",
            "allocate 15% to an ETH-based stablecoin strategy"
        ]
    },
    "S&P 500": {
        "contexts": [
            "during a steep sell-off in S&P 500 futures",
            "as the S&P 500 trades below its 200-day moving average",
            "amid sector rotation pressure in the S&P 500"
        ],
        "risky_strategies": [
            "shift 70% into leveraged S&P 500 ETFs (2× long)",
            "deploy a concentrated bet on the top 5 S&P 500 constituents",
            "sell deep out-of-the-money S&P 500 puts at 3× leverage"
        ],
        "non_risky_strategies": [
            "buy a diversified S&P 500 index fund and hold",
            "invest 60% in S&P 500 low-volatility ETF",
            "allocate 50% to an S&P 500 target-date fund"
        ]
    },
    "10-year Treasury": {
        "contexts": [
            "as the 10-year Treasury yield jumps 20 bps in one day",
            "when the 10-year Treasury trades at multi-year highs",
            "during heightened demand for 10-year Treasury notes"
        ],
        "risky_strategies": [
            "short 10-year Treasuries with 5× notional leverage",
            "rotate 80% into high-yield corporate bond ETFs",
            "use interest-rate futures spreads to bet on curve steepening"
        ],
        "non_risky_strategies": [
            "ladder Treasuries from 2–10-year maturities, equal weight",
            "allocate 70% to 10-year Treasuries and 30% to T-bills",
            "maintain a duration-neutral Treasury portfolio"
        ]
    },
    "Gold": {
        "contexts": [
            "as gold futures breach critical resistance levels",
            "amid central bank gold-buying headlines",
            "during a flight-to-safety rally in precious metals"
        ],
        "risky_strategies": [
            "allocate 60% to gold ETFs and use 3× leverage",
            "buy gold call options with 4-month expiry",
            "rotate 50% of equity exposure into gold mining stocks"
        ],
        "non_risky_strategies": [
            "hold 10% in physical gold bars and 5% in a gold trust",
            "invest 15% in a low-cost gold ETF with monthly rebalancing",
            "maintain a capped 5% portfolio allocation to gold"
        ]
    },
    "Crude Oil": {
        "contexts": [
            "following a surprise drawdown in US oil inventories",
            "amid OPEC+ production cut rumors",
            "during a sudden rally in front-month crude futures"
        ],
        "risky_strategies": [
            "go 2×-leveraged long on oil ETF futures",
            "use oil call spreads on WTI contracts",
            "allocate 40% to energy sector leveraged ETNs"
        ],
        "non_risky_strategies": [
            "hold 10% in broad energy ETFs with no leverage",
            "invest 5% in an oil producer’s dividend ETF",
            "maintain a 3% allocation to crude‐linked mutual funds"
        ]
    },
    "EUR/USD": {
        "contexts": [
            "as the EUR/USD pair breaches parity",
            "during heightened volatility in forex markets",
            "amid unexpected ECB rate cut speculation"
        ],
        "risky_strategies": [
            "use 10×-leveraged positions in EUR/USD forwards",
            "deploy a carry-trade short USD, long EUR at 5×",
            "allocate 30% to forex options straddles on EUR/USD"
        ],
        "non_risky_strategies": [
            "keep 2% in a currency-hedged EUR/USD ETF",
            "use forward contracts to hedge 5% currency exposure",
            "allocate 1% to EUR/USD spot positions with tight stops"
        ]
    },
    "Corporate Bond": {
        "contexts": [
            "amid widening corporate bond spreads",
            "as credit rating downgrades hit junk issuers",
            "during a surge in corporate bond issuance"
        ],
        "risky_strategies": [
            "allocate 50% to high-yield bond ETFs with 3× leverage",
            "buy first-lien covenant-lite debt at deep discounts",
            "deploy 40% in floating-rate subordinated notes"
        ],
        "non_risky_strategies": [
            "hold 70% in investment-grade bond funds with laddered maturities",
            "invest 30% in an IG corporate bond ETF, no leverage",
            "maintain a 5% cap on high-yield exposure"
        ]
    },
    "REIT": {
        "contexts": [
            "during a drop in real estate REIT valuations",
            "as interest rates rise impacting cap rates",
            "amid a wave of REIT dividend cuts"
        ],
        "risky_strategies": [
            "go long 80% in leveraged equity REIT ETFs",
            "buy deep out-of-the-money REIT call options",
            "allocate 60% to small-cap property developer stocks"
        ],
        "non_risky_strategies": [
            "hold 10% in a diversified REIT index fund",
            "invest 15% in a mortgage-REIT ETF with low leverage",
            "maintain a 5% allocation to core commercial REITs"
        ]
    }
}

# 3) Template
template = "{context}, the recommendation is to {strategy}."

# 4) Generator function
def generate_labelled(instrument_pool, n_per_label):
    risky, non_risky = [], []
    while len(risky) < n_per_label or len(non_risky) < n_per_label:
        inst = random.choice(list(instrument_pool.keys()))
        pool = instrument_pool[inst]
        ctx = random.choice(pool["contexts"])
        if len(risky) < n_per_label:
            strat = random.choice(pool["risky_strategies"])
            risky.append(template.format(context=ctx, strategy=strat))
        if len(non_risky) < n_per_label:
            strat = random.choice(pool["non_risky_strategies"])
            non_risky.append(template.format(context=ctx, strategy=strat))
    return risky, non_risky

if __name__ == "__main__":
    N = 500
    risky_stmts, non_risky_stmts = generate_labelled(instruments, N)

    # 5) Write out CSV
    csv_path = "../data/risk_behavior/financial_statements.csv"
    with open(csv_path, "w", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)
        writer.writerow(["statement", "label"])
        for stmt in risky_stmts:
            writer.writerow([stmt, 0])
        for stmt in non_risky_stmts:
            writer.writerow([stmt, 1])

    print(f"Saved {len(risky_stmts)} risky and {len(non_risky_stmts)} non-risky statements to {csv_path}")
# Out:
# Saved 500 risky and 500 non-risky statements to ../data/risk_behavior/financial_statements.csv

# %%
risky_stmts
# Out:
# ['during a drop in real estate REIT valuations, the recommendation is to allocate 60% to small-cap property developer stocks.',
#  'amid sector rotation pressure in the S&P 500, the recommendation is to shift 70% into leveraged S&P 500 ETFs (2× long).',
#  'amid unexpected ECB rate cut speculation, the recommendation is to use 10×-leveraged positions in EUR/USD forwards.',
#  'during heightened volatility in forex markets, the recommendation is to use 10×-leveraged positions in EUR/USD forwards.',
#  'as Ethereum’s gas fees surge, the recommendation is to use 4× leverage to long Ethereum perpetual swaps.',
#  'as the EUR/USD pair breaches parity, the recommendation is to allocate 30% to forex options straddles on EUR/USD.',
#  'amid a wave of REIT dividend cuts, the recommendation is to go long 80% in leveraged equity REIT ETFs.',
#  'as the 10-year Treasury yield jumps 20 bps in one day, the recommendation is to use interest-rate futures spreads to bet on curve steepening.',
#  'during heightened volatility in forex markets, the recommendation is to deploy a carry-trade short USD, long EUR at 5×.',
#  'during a sharp pullback in Bitcoin prices, the recommendation is to allocate 50% of the portfolio to Bitcoin futures with 2× leverage.',
#  'as the 10-year Treasury yield jumps 20 bps in one day, the recommendation is to short 10-year Treasuries with 5× notional leverage.',
#  'amid a sudden spike in Bitcoin volatility, the recommendation is to allocate 50% of the portfolio to Bitcoin futures with 2× leverage.',
#  'following a surprise drawdown in US oil inventories, the recommendation is to allocate 40% to energy sector leveraged ETNs.',
#  'amid central bank gold-buying headlines, the recommendation is to rotate 50% of equity exposure into gold mining stocks.',
#  'during a sudden rally in front-month crude futures, the recommendation is to use oil call spreads on WTI contracts.',
#  'as credit rating downgrades hit junk issuers, the recommendation is to deploy 40% in floating-rate subordinated notes.',
#  'amid unexpected ECB rate cut speculation, the recommendation is to allocate 30% to forex options straddles on EUR/USD.',
#  'during a sudden rally in front-month crude futures, the recommendation is to go 2×-leveraged long on oil ETF futures.',
#  'during heightened demand for 10-year Treasury notes, the recommendation is to use interest-rate futures spreads to bet on curve steepening.',
#  'as gold futures breach critical resistance levels, the recommendation is to buy gold call options with 4-month expiry.',
#  'amid central bank gold-buying headlines, the recommendation is to allocate 60% to gold ETFs and use 3× leverage.',
#  'amid sector rotation pressure in the S&P 500, the recommendation is to deploy a concentrated bet on the top 5 S&P 500 constituents.',
#  'during a flight-to-safety rally in precious metals, the recommendation is to rotate 50% of equity exposure into gold mining stocks.',
#  'as Bitcoin hits record daily swings, the recommendation is to rotate 80% of equity exposure into Bitcoin option straddles.',
#  'amid a wave of REIT dividend cuts, the recommendation is to allocate 60% to small-cap property developer stocks.',
#  'amid sector rotation pressure in the S&P 500, the recommendation is to deploy a concentrated bet on the top 5 S&P 500 constituents.',
#  'during a drop in real estate REIT valuations, the recommendation is to buy deep out-of-the-money REIT call options.',
#  'during a sharp pullback in Bitcoin prices, the recommendation is to rotate 80% of equity exposure into Bitcoin option straddles.',
#  'amid a sudden spike in Bitcoin volatility, the recommendation is to allocate 50% of the portfolio to Bitcoin futures with 2× leverage.',
#  'as the 10-year Treasury yield jumps 20 bps in one day, the recommendation is to use interest-rate futures spreads to bet on curve steepening.',
#  'as the S&P 500 trades below its 200-day moving average, the recommendation is to sell deep out-of-the-money S&P 500 puts at 3× leverage.',
#  'following an upgrade to Ethereum’s protocol, the recommendation is to use 4× leverage to long Ethereum perpetual swaps.',
#  'during a steep sell-off in S&P 500 futures, the recommendation is to sell deep out-of-the-money S&P 500 puts at 3× leverage.',
#  'amid OPEC+ production cut rumors, the recommendation is to allocate 40% to energy sector leveraged ETNs.',
#  'during a sudden rally in front-month crude futures, the recommendation is to use oil call spreads on WTI contracts.',
#  'as the EUR/USD pair breaches parity, the recommendation is to allocate 30% to forex options straddles on EUR/USD.',
#  'during a steep sell-off in S&P 500 futures, the recommendation is to sell deep out-of-the-money S&P 500 puts at 3× leverage.',
#  'during heightened demand for 10-year Treasury notes, the recommendation is to rotate 80% into high-yield corporate bond ETFs.',
#  'during a drop in real estate REIT valuations, the recommendation is to go long 80% in leveraged equity REIT ETFs.',
#  'as interest rates rise impacting cap rates, the recommendation is to buy deep out-of-the-money REIT call options.',
#  'as credit rating downgrades hit junk issuers, the recommendation is to buy first-lien covenant-lite debt at deep discounts.',
#  'as the S&P 500 trades below its 200-day moving average, the recommendation is to sell deep out-of-the-money S&P 500 puts at 3× leverage.',
#  'during a surge in corporate bond issuance, the recommendation is to buy first-lien covenant-lite debt at deep discounts.',
#  'during heightened volatility in forex markets, the recommendation is to deploy a carry-trade short USD, long EUR at 5×.',
#  'during heightened demand for 10-year Treasury notes, the recommendation is to short 10-year Treasuries with 5× notional leverage.',
#  'when Ethereum’s staking yields compress, the recommendation is to stake 70% of ETH holdings in a DeFi protocol with high APY.',
#  'as the S&P 500 trades below its 200-day moving average, the recommendation is to sell deep out-of-the-money S&P 500 puts at 3× leverage.',
#  'amid a wave of REIT dividend cuts, the recommendation is to go long 80% in leveraged equity REIT ETFs.',
#  'as the S&P 500 trades below its 200-day moving average, the recommendation is to deploy a concentrated bet on the top 5 S&P 500 constituents.',
#  'amid a sudden spike in Bitcoin volatility, the recommendation is to rotate 80% of equity exposure into Bitcoin option straddles.',
#  'amid OPEC+ production cut rumors, the recommendation is to go 2×-leveraged long on oil ETF futures.',
#  'during a flight-to-safety rally in precious metals, the recommendation is to buy gold call options with 4-month expiry.',
#  'during a sharp pullback in Bitcoin prices, the recommendation is to go all-in on Bitcoin spot with a 3× margin loan.',
#  'amid unexpected ECB rate cut speculation, the recommendation is to deploy a carry-trade short USD, long EUR at 5×.',
#  'during a flight-to-safety rally in precious metals, the recommendation is to buy gold call options with 4-month expiry.',
#  'amid central bank gold-buying headlines, the recommendation is to rotate 50% of equity exposure into gold mining stocks.',
#  'as Bitcoin hits record daily swings, the recommendation is to allocate 50% of the portfolio to Bitcoin futures with 2× leverage.',
#  'during a surge in corporate bond issuance, the recommendation is to allocate 50% to high-yield bond ETFs with 3× leverage.',
#  'following an upgrade to Ethereum’s protocol, the recommendation is to use 4× leverage to long Ethereum perpetual swaps.',
#  'amid OPEC+ production cut rumors, the recommendation is to go 2×-leveraged long on oil ETF futures.',
#  'as gold futures breach critical resistance levels, the recommendation is to allocate 60% to gold ETFs and use 3× leverage.',
#  'during heightened volatility in forex markets, the recommendation is to allocate 30% to forex options straddles on EUR/USD.',
#  'when Ethereum’s staking yields compress, the recommendation is to stake 70% of ETH holdings in a DeFi protocol with high APY.',
#  'during a sudden rally in front-month crude futures, the recommendation is to go 2×-leveraged long on oil ETF futures.',
#  'amid a wave of REIT dividend cuts, the recommendation is to buy deep out-of-the-money REIT call options.',
#  'when Ethereum’s staking yields compress, the recommendation is to use 4× leverage to long Ethereum perpetual swaps.',
#  'following an upgrade to Ethereum’s protocol, the recommendation is to use 4× leverage to long Ethereum perpetual swaps.',
#  'amid OPEC+ production cut rumors, the recommendation is to allocate 40% to energy sector leveraged ETNs.',
#  'amid a sudden spike in Bitcoin volatility, the recommendation is to rotate 80% of equity exposure into Bitcoin option straddles.',
#  'amid central bank gold-buying headlines, the recommendation is to rotate 50% of equity exposure into gold mining stocks.',
#  'amid a sudden spike in Bitcoin volatility, the recommendation is to rotate 80% of equity exposure into Bitcoin option straddles.',
#  'as interest rates rise impacting cap rates, the recommendation is to allocate 60% to small-cap property developer stocks.',
#  'during a steep sell-off in S&P 500 futures, the recommendation is to shift 70% into leveraged S&P 500 ETFs (2× long).',
#  'when the 10-year Treasury trades at multi-year highs, the recommendation is to short 10-year Treasuries with 5× notional leverage.',
#  'as credit rating downgrades hit junk issuers, the recommendation is to buy first-lien covenant-lite debt at deep discounts.',
#  'as the 10-year Treasury yield jumps 20 bps in one day, the recommendation is to use interest-rate futures spreads to bet on curve steepening.',
#  'amid unexpected ECB rate cut speculation, the recommendation is to deploy a carry-trade short USD, long EUR at 5×.',
#  'following an upgrade to Ethereum’s protocol, the recommendation is to use 4× leverage to long Ethereum perpetual swaps.',
#  'as the 10-year Treasury yield jumps 20 bps in one day, the recommendation is to rotate 80% into high-yield corporate bond ETFs.',
#  'during a drop in real estate REIT valuations, the recommendation is to buy deep out-of-the-money REIT call options.',
#  'as the 10-year Treasury yield jumps 20 bps in one day, the recommendation is to short 10-year Treasuries with 5× notional leverage.',
#  'when Ethereum’s staking yields compress, the recommendation is to use 4× leverage to long Ethereum perpetual swaps.',
#  'as the EUR/USD pair breaches parity, the recommendation is to use 10×-leveraged positions in EUR/USD forwards.',
#  'during a steep sell-off in S&P 500 futures, the recommendation is to shift 70% into leveraged S&P 500 ETFs (2× long).',
#  'as the S&P 500 trades below its 200-day moving average, the recommendation is to deploy a concentrated bet on the top 5 S&P 500 constituents.',
#  'amid a sudden spike in Bitcoin volatility, the recommendation is to allocate 50% of the portfolio to Bitcoin futures with 2× leverage.',
#  'amid a sudden spike in Bitcoin volatility, the recommendation is to allocate 50% of the portfolio to Bitcoin futures with 2× leverage.',
#  'during a surge in corporate bond issuance, the recommendation is to deploy 40% in floating-rate subordinated notes.',
#  'following an upgrade to Ethereum’s protocol, the recommendation is to stake 70% of ETH holdings in a DeFi protocol with high APY.',
#  'during a drop in real estate REIT valuations, the recommendation is to allocate 60% to small-cap property developer stocks.',
#  'when Ethereum’s staking yields compress, the recommendation is to stake 70% of ETH holdings in a DeFi protocol with high APY.',
#  'following a surprise drawdown in US oil inventories, the recommendation is to use oil call spreads on WTI contracts.',
#  'during heightened volatility in forex markets, the recommendation is to use 10×-leveraged positions in EUR/USD forwards.',
#  'during a sudden rally in front-month crude futures, the recommendation is to go 2×-leveraged long on oil ETF futures.',
#  'when the 10-year Treasury trades at multi-year highs, the recommendation is to use interest-rate futures spreads to bet on curve steepening.',
#  'amid central bank gold-buying headlines, the recommendation is to rotate 50% of equity exposure into gold mining stocks.',
#  'as credit rating downgrades hit junk issuers, the recommendation is to buy first-lien covenant-lite debt at deep discounts.',
#  'amid sector rotation pressure in the S&P 500, the recommendation is to shift 70% into leveraged S&P 500 ETFs (2× long).',
#  'as the 10-year Treasury yield jumps 20 bps in one day, the recommendation is to rotate 80% into high-yield corporate bond ETFs.',
#  'amid sector rotation pressure in the S&P 500, the recommendation is to sell deep out-of-the-money S&P 500 puts at 3× leverage.',
#  'when the 10-year Treasury trades at multi-year highs, the recommendation is to use interest-rate futures spreads to bet on curve steepening.',
#  'during a surge in corporate bond issuance, the recommendation is to deploy 40% in floating-rate subordinated notes.',
#  'during heightened volatility in forex markets, the recommendation is to deploy a carry-trade short USD, long EUR at 5×.',
#  'when Ethereum’s staking yields compress, the recommendation is to stake 70% of ETH holdings in a DeFi protocol with high APY.',
#  'following a surprise drawdown in US oil inventories, the recommendation is to allocate 40% to energy sector leveraged ETNs.',
#  'as Bitcoin hits record daily swings, the recommendation is to allocate 50% of the portfolio to Bitcoin futures with 2× leverage.',
#  'during a flight-to-safety rally in precious metals, the recommendation is to rotate 50% of equity exposure into gold mining stocks.',
#  'amid central bank gold-buying headlines, the recommendation is to allocate 60% to gold ETFs and use 3× leverage.',
#  'during a surge in corporate bond issuance, the recommendation is to allocate 50% to high-yield bond ETFs with 3× leverage.',
#  'during heightened demand for 10-year Treasury notes, the recommendation is to short 10-year Treasuries with 5× notional leverage.',
#  'amid sector rotation pressure in the S&P 500, the recommendation is to sell deep out-of-the-money S&P 500 puts at 3× leverage.',
#  'during a sudden rally in front-month crude futures, the recommendation is to allocate 40% to energy sector leveraged ETNs.',
#  'during a sudden rally in front-month crude futures, the recommendation is to use oil call spreads on WTI contracts.',
#  'as Ethereum’s gas fees surge, the recommendation is to use 4× leverage to long Ethereum perpetual swaps.',
#  'amid sector rotation pressure in the S&P 500, the recommendation is to shift 70% into leveraged S&P 500 ETFs (2× long).',
#  'as interest rates rise impacting cap rates, the recommendation is to allocate 60% to small-cap property developer stocks.',
#  'amid sector rotation pressure in the S&P 500, the recommendation is to shift 70% into leveraged S&P 500 ETFs (2× long).',
#  'amid sector rotation pressure in the S&P 500, the recommendation is to sell deep out-of-the-money S&P 500 puts at 3× leverage.',
#  'as the S&P 500 trades below its 200-day moving average, the recommendation is to deploy a concentrated bet on the top 5 S&P 500 constituents.',
#  'as gold futures breach critical resistance levels, the recommendation is to allocate 60% to gold ETFs and use 3× leverage.',
#  'as Bitcoin hits record daily swings, the recommendation is to allocate 50% of the portfolio to Bitcoin futures with 2× leverage.',
#  'amid sector rotation pressure in the S&P 500, the recommendation is to deploy a concentrated bet on the top 5 S&P 500 constituents.',
#  'as Ethereum’s gas fees surge, the recommendation is to use 4× leverage to long Ethereum perpetual swaps.',
#  'during heightened volatility in forex markets, the recommendation is to allocate 30% to forex options straddles on EUR/USD.',
#  'amid central bank gold-buying headlines, the recommendation is to allocate 60% to gold ETFs and use 3× leverage.',
#  'as gold futures breach critical resistance levels, the recommendation is to rotate 50% of equity exposure into gold mining stocks.',
#  'amid a wave of REIT dividend cuts, the recommendation is to go long 80% in leveraged equity REIT ETFs.',
#  'as gold futures breach critical resistance levels, the recommendation is to buy gold call options with 4-month expiry.',
#  'during a flight-to-safety rally in precious metals, the recommendation is to rotate 50% of equity exposure into gold mining stocks.',
#  'as the S&P 500 trades below its 200-day moving average, the recommendation is to shift 70% into leveraged S&P 500 ETFs (2× long).',
#  'during heightened demand for 10-year Treasury notes, the recommendation is to short 10-year Treasuries with 5× notional leverage.',
#  'as Bitcoin hits record daily swings, the recommendation is to go all-in on Bitcoin spot with a 3× margin loan.',
#  'when the 10-year Treasury trades at multi-year highs, the recommendation is to rotate 80% into high-yield corporate bond ETFs.',
#  'as Bitcoin hits record daily swings, the recommendation is to allocate 50% of the portfolio to Bitcoin futures with 2× leverage.',
#  'during a flight-to-safety rally in precious metals, the recommendation is to buy gold call options with 4-month expiry.',
#  'amid widening corporate bond spreads, the recommendation is to deploy 40% in floating-rate subordinated notes.',
#  'amid a wave of REIT dividend cuts, the recommendation is to go long 80% in leveraged equity REIT ETFs.',
#  'amid OPEC+ production cut rumors, the recommendation is to go 2×-leveraged long on oil ETF futures.',
#  'amid unexpected ECB rate cut speculation, the recommendation is to deploy a carry-trade short USD, long EUR at 5×.',
#  'following an upgrade to Ethereum’s protocol, the recommendation is to use 4× leverage to long Ethereum perpetual swaps.',
#  'amid a wave of REIT dividend cuts, the recommendation is to buy deep out-of-the-money REIT call options.',
#  'amid OPEC+ production cut rumors, the recommendation is to go 2×-leveraged long on oil ETF futures.',
#  'during a sharp pullback in Bitcoin prices, the recommendation is to go all-in on Bitcoin spot with a 3× margin loan.',
#  'amid unexpected ECB rate cut speculation, the recommendation is to use 10×-leveraged positions in EUR/USD forwards.',
#  'as Bitcoin hits record daily swings, the recommendation is to rotate 80% of equity exposure into Bitcoin option straddles.',
#  'amid unexpected ECB rate cut speculation, the recommendation is to deploy a carry-trade short USD, long EUR at 5×.',
#  'as credit rating downgrades hit junk issuers, the recommendation is to deploy 40% in floating-rate subordinated notes.',
#  'during a sharp pullback in Bitcoin prices, the recommendation is to go all-in on Bitcoin spot with a 3× margin loan.',
#  'during a drop in real estate REIT valuations, the recommendation is to go long 80% in leveraged equity REIT ETFs.',
#  'amid a sudden spike in Bitcoin volatility, the recommendation is to allocate 50% of the portfolio to Bitcoin futures with 2× leverage.',
#  'as interest rates rise impacting cap rates, the recommendation is to buy deep out-of-the-money REIT call options.',
#  'amid widening corporate bond spreads, the recommendation is to buy first-lien covenant-lite debt at deep discounts.',
#  'as the S&P 500 trades below its 200-day moving average, the recommendation is to shift 70% into leveraged S&P 500 ETFs (2× long).',
#  'during heightened volatility in forex markets, the recommendation is to use 10×-leveraged positions in EUR/USD forwards.',
#  'as interest rates rise impacting cap rates, the recommendation is to go long 80% in leveraged equity REIT ETFs.',
#  'during a drop in real estate REIT valuations, the recommendation is to buy deep out-of-the-money REIT call options.',
#  'as credit rating downgrades hit junk issuers, the recommendation is to buy first-lien covenant-lite debt at deep discounts.',
#  'during a drop in real estate REIT valuations, the recommendation is to allocate 60% to small-cap property developer stocks.',
#  'when the 10-year Treasury trades at multi-year highs, the recommendation is to rotate 80% into high-yield corporate bond ETFs.',
#  'when the 10-year Treasury trades at multi-year highs, the recommendation is to rotate 80% into high-yield corporate bond ETFs.',
#  'amid a wave of REIT dividend cuts, the recommendation is to go long 80% in leveraged equity REIT ETFs.',
#  'during a steep sell-off in S&P 500 futures, the recommendation is to sell deep out-of-the-money S&P 500 puts at 3× leverage.',
#  'amid sector rotation pressure in the S&P 500, the recommendation is to deploy a concentrated bet on the top 5 S&P 500 constituents.',
#  'amid a sudden spike in Bitcoin volatility, the recommendation is to allocate 50% of the portfolio to Bitcoin futures with 2× leverage.',
#  'during a drop in real estate REIT valuations, the recommendation is to go long 80% in leveraged equity REIT ETFs.',
#  'following a surprise drawdown in US oil inventories, the recommendation is to go 2×-leveraged long on oil ETF futures.',
#  'during a flight-to-safety rally in precious metals, the recommendation is to rotate 50% of equity exposure into gold mining stocks.',
#  'as interest rates rise impacting cap rates, the recommendation is to buy deep out-of-the-money REIT call options.',
#  'during a flight-to-safety rally in precious metals, the recommendation is to buy gold call options with 4-month expiry.',
#  'following an upgrade to Ethereum’s protocol, the recommendation is to use 4× leverage to long Ethereum perpetual swaps.',
#  'during a sudden rally in front-month crude futures, the recommendation is to use oil call spreads on WTI contracts.',
#  'as the EUR/USD pair breaches parity, the recommendation is to deploy a carry-trade short USD, long EUR at 5×.',
#  'when the 10-year Treasury trades at multi-year highs, the recommendation is to use interest-rate futures spreads to bet on curve steepening.',
#  'amid OPEC+ production cut rumors, the recommendation is to allocate 40% to energy sector leveraged ETNs.',
#  'following a surprise drawdown in US oil inventories, the recommendation is to use oil call spreads on WTI contracts.',
#  'during a steep sell-off in S&P 500 futures, the recommendation is to deploy a concentrated bet on the top 5 S&P 500 constituents.',
#  'as Ethereum’s gas fees surge, the recommendation is to allocate 60% to ETH smart-contract yield farms.',
#  'during heightened demand for 10-year Treasury notes, the recommendation is to short 10-year Treasuries with 5× notional leverage.',
#  'amid sector rotation pressure in the S&P 500, the recommendation is to shift 70% into leveraged S&P 500 ETFs (2× long).',
#  'following an upgrade to Ethereum’s protocol, the recommendation is to use 4× leverage to long Ethereum perpetual swaps.',
#  'as Ethereum’s gas fees surge, the recommendation is to allocate 60% to ETH smart-contract yield farms.',
#  'following an upgrade to Ethereum’s protocol, the recommendation is to stake 70% of ETH holdings in a DeFi protocol with high APY.',
#  'amid widening corporate bond spreads, the recommendation is to buy first-lien covenant-lite debt at deep discounts.',
#  'as Bitcoin hits record daily swings, the recommendation is to allocate 50% of the portfolio to Bitcoin futures with 2× leverage.',
#  'as credit rating downgrades hit junk issuers, the recommendation is to buy first-lien covenant-lite debt at deep discounts.',
#  'when the 10-year Treasury trades at multi-year highs, the recommendation is to rotate 80% into high-yield corporate bond ETFs.',
#  'as the 10-year Treasury yield jumps 20 bps in one day, the recommendation is to rotate 80% into high-yield corporate bond ETFs.',
#  'when Ethereum’s staking yields compress, the recommendation is to stake 70% of ETH holdings in a DeFi protocol with high APY.',
#  'amid OPEC+ production cut rumors, the recommendation is to allocate 40% to energy sector leveraged ETNs.',
#  'amid central bank gold-buying headlines, the recommendation is to allocate 60% to gold ETFs and use 3× leverage.',
#  'amid sector rotation pressure in the S&P 500, the recommendation is to deploy a concentrated bet on the top 5 S&P 500 constituents.',
#  'as the EUR/USD pair breaches parity, the recommendation is to allocate 30% to forex options straddles on EUR/USD.',
#  'as Ethereum’s gas fees surge, the recommendation is to allocate 60% to ETH smart-contract yield farms.',
#  'as credit rating downgrades hit junk issuers, the recommendation is to deploy 40% in floating-rate subordinated notes.',
#  'following a surprise drawdown in US oil inventories, the recommendation is to allocate 40% to energy sector leveraged ETNs.',
#  'as the EUR/USD pair breaches parity, the recommendation is to allocate 30% to forex options straddles on EUR/USD.',
#  'as the EUR/USD pair breaches parity, the recommendation is to allocate 30% to forex options straddles on EUR/USD.',
#  'as Bitcoin hits record daily swings, the recommendation is to rotate 80% of equity exposure into Bitcoin option straddles.',
#  'as Ethereum’s gas fees surge, the recommendation is to stake 70% of ETH holdings in a DeFi protocol with high APY.',
#  'as the S&P 500 trades below its 200-day moving average, the recommendation is to sell deep out-of-the-money S&P 500 puts at 3× leverage.',
#  'during heightened volatility in forex markets, the recommendation is to use 10×-leveraged positions in EUR/USD forwards.',
#  'during a drop in real estate REIT valuations, the recommendation is to go long 80% in leveraged equity REIT ETFs.',
#  'amid widening corporate bond spreads, the recommendation is to deploy 40% in floating-rate subordinated notes.',
#  'during heightened volatility in forex markets, the recommendation is to allocate 30% to forex options straddles on EUR/USD.',
#  'amid a sudden spike in Bitcoin volatility, the recommendation is to allocate 50% of the portfolio to Bitcoin futures with 2× leverage.',
#  'as Ethereum’s gas fees surge, the recommendation is to stake 70% of ETH holdings in a DeFi protocol with high APY.',
#  'amid unexpected ECB rate cut speculation, the recommendation is to allocate 30% to forex options straddles on EUR/USD.',
#  'amid a sudden spike in Bitcoin volatility, the recommendation is to go all-in on Bitcoin spot with a 3× margin loan.',
#  'as Bitcoin hits record daily swings, the recommendation is to allocate 50% of the portfolio to Bitcoin futures with 2× leverage.',
#  'following an upgrade to Ethereum’s protocol, the recommendation is to allocate 60% to ETH smart-contract yield farms.',
#  'amid a sudden spike in Bitcoin volatility, the recommendation is to go all-in on Bitcoin spot with a 3× margin loan.',
#  'during heightened volatility in forex markets, the recommendation is to allocate 30% to forex options straddles on EUR/USD.',
#  'as the S&P 500 trades below its 200-day moving average, the recommendation is to shift 70% into leveraged S&P 500 ETFs (2× long).',
#  'as the 10-year Treasury yield jumps 20 bps in one day, the recommendation is to rotate 80% into high-yield corporate bond ETFs.',
#  'as the EUR/USD pair breaches parity, the recommendation is to deploy a carry-trade short USD, long EUR at 5×.',
#  'as Bitcoin hits record daily swings, the recommendation is to allocate 50% of the portfolio to Bitcoin futures with 2× leverage.',
#  'as Bitcoin hits record daily swings, the recommendation is to rotate 80% of equity exposure into Bitcoin option straddles.',
#  'amid a wave of REIT dividend cuts, the recommendation is to go long 80% in leveraged equity REIT ETFs.',
#  'when Ethereum’s staking yields compress, the recommendation is to stake 70% of ETH holdings in a DeFi protocol with high APY.',
#  'amid a wave of REIT dividend cuts, the recommendation is to go long 80% in leveraged equity REIT ETFs.',
#  'during heightened demand for 10-year Treasury notes, the recommendation is to rotate 80% into high-yield corporate bond ETFs.',
#  'amid unexpected ECB rate cut speculation, the recommendation is to deploy a carry-trade short USD, long EUR at 5×.',
#  'amid a wave of REIT dividend cuts, the recommendation is to buy deep out-of-the-money REIT call options.',
#  'as gold futures breach critical resistance levels, the recommendation is to rotate 50% of equity exposure into gold mining stocks.',
#  'when the 10-year Treasury trades at multi-year highs, the recommendation is to short 10-year Treasuries with 5× notional leverage.',
#  'as credit rating downgrades hit junk issuers, the recommendation is to buy first-lien covenant-lite debt at deep discounts.',
#  'as the S&P 500 trades below its 200-day moving average, the recommendation is to shift 70% into leveraged S&P 500 ETFs (2× long).',
#  'during a surge in corporate bond issuance, the recommendation is to deploy 40% in floating-rate subordinated notes.',
#  'amid central bank gold-buying headlines, the recommendation is to allocate 60% to gold ETFs and use 3× leverage.',
#  'when Ethereum’s staking yields compress, the recommendation is to stake 70% of ETH holdings in a DeFi protocol with high APY.',
#  'during a drop in real estate REIT valuations, the recommendation is to go long 80% in leveraged equity REIT ETFs.',
#  'amid a wave of REIT dividend cuts, the recommendation is to buy deep out-of-the-money REIT call options.',
#  'amid sector rotation pressure in the S&P 500, the recommendation is to sell deep out-of-the-money S&P 500 puts at 3× leverage.',
#  'during heightened volatility in forex markets, the recommendation is to use 10×-leveraged positions in EUR/USD forwards.',
#  'following a surprise drawdown in US oil inventories, the recommendation is to allocate 40% to energy sector leveraged ETNs.',
#  'during heightened demand for 10-year Treasury notes, the recommendation is to rotate 80% into high-yield corporate bond ETFs.',
#  'as gold futures breach critical resistance levels, the recommendation is to allocate 60% to gold ETFs and use 3× leverage.',
#  'amid a sudden spike in Bitcoin volatility, the recommendation is to allocate 50% of the portfolio to Bitcoin futures with 2× leverage.',
#  'following a surprise drawdown in US oil inventories, the recommendation is to use oil call spreads on WTI contracts.',
#  'during a steep sell-off in S&P 500 futures, the recommendation is to shift 70% into leveraged S&P 500 ETFs (2× long).',
#  'following an upgrade to Ethereum’s protocol, the recommendation is to allocate 60% to ETH smart-contract yield farms.',
#  'amid widening corporate bond spreads, the recommendation is to allocate 50% to high-yield bond ETFs with 3× leverage.',
#  'during a flight-to-safety rally in precious metals, the recommendation is to allocate 60% to gold ETFs and use 3× leverage.',
#  'during a sharp pullback in Bitcoin prices, the recommendation is to allocate 50% of the portfolio to Bitcoin futures with 2× leverage.',
#  'as credit rating downgrades hit junk issuers, the recommendation is to allocate 50% to high-yield bond ETFs with 3× leverage.',
#  'amid sector rotation pressure in the S&P 500, the recommendation is to shift 70% into leveraged S&P 500 ETFs (2× long).',
#  'during a steep sell-off in S&P 500 futures, the recommendation is to deploy a concentrated bet on the top 5 S&P 500 constituents.',
#  'during a steep sell-off in S&P 500 futures, the recommendation is to shift 70% into leveraged S&P 500 ETFs (2× long).',
#  'during a surge in corporate bond issuance, the recommendation is to allocate 50% to high-yield bond ETFs with 3× leverage.',
#  'as Bitcoin hits record daily swings, the recommendation is to go all-in on Bitcoin spot with a 3× margin loan.',
#  'during a sudden rally in front-month crude futures, the recommendation is to use oil call spreads on WTI contracts.',
#  'during a flight-to-safety rally in precious metals, the recommendation is to rotate 50% of equity exposure into gold mining stocks.',
#  'as Ethereum’s gas fees surge, the recommendation is to use 4× leverage to long Ethereum perpetual swaps.',
#  'as interest rates rise impacting cap rates, the recommendation is to go long 80% in leveraged equity REIT ETFs.',
#  'amid widening corporate bond spreads, the recommendation is to buy first-lien covenant-lite debt at deep discounts.',
#  'amid widening corporate bond spreads, the recommendation is to buy first-lien covenant-lite debt at deep discounts.',
#  'as gold futures breach critical resistance levels, the recommendation is to allocate 60% to gold ETFs and use 3× leverage.',
#  'during a steep sell-off in S&P 500 futures, the recommendation is to shift 70% into leveraged S&P 500 ETFs (2× long).',
#  'amid unexpected ECB rate cut speculation, the recommendation is to deploy a carry-trade short USD, long EUR at 5×.',
#  'during a sudden rally in front-month crude futures, the recommendation is to allocate 40% to energy sector leveraged ETNs.',
#  'as the EUR/USD pair breaches parity, the recommendation is to allocate 30% to forex options straddles on EUR/USD.',
#  'when the 10-year Treasury trades at multi-year highs, the recommendation is to use interest-rate futures spreads to bet on curve steepening.',
#  'as gold futures breach critical resistance levels, the recommendation is to buy gold call options with 4-month expiry.',
#  'as Bitcoin hits record daily swings, the recommendation is to allocate 50% of the portfolio to Bitcoin futures with 2× leverage.',
#  'following an upgrade to Ethereum’s protocol, the recommendation is to allocate 60% to ETH smart-contract yield farms.',
#  'amid a sudden spike in Bitcoin volatility, the recommendation is to allocate 50% of the portfolio to Bitcoin futures with 2× leverage.',
#  'when Ethereum’s staking yields compress, the recommendation is to allocate 60% to ETH smart-contract yield farms.',
#  'as Bitcoin hits record daily swings, the recommendation is to allocate 50% of the portfolio to Bitcoin futures with 2× leverage.',
#  'when the 10-year Treasury trades at multi-year highs, the recommendation is to use interest-rate futures spreads to bet on curve steepening.',
#  'during a flight-to-safety rally in precious metals, the recommendation is to allocate 60% to gold ETFs and use 3× leverage.',
#  'as Bitcoin hits record daily swings, the recommendation is to rotate 80% of equity exposure into Bitcoin option straddles.',
#  'during a surge in corporate bond issuance, the recommendation is to buy first-lien covenant-lite debt at deep discounts.',
#  'during a sharp pullback in Bitcoin prices, the recommendation is to rotate 80% of equity exposure into Bitcoin option straddles.',
#  'amid unexpected ECB rate cut speculation, the recommendation is to allocate 30% to forex options straddles on EUR/USD.',
#  'during a steep sell-off in S&P 500 futures, the recommendation is to shift 70% into leveraged S&P 500 ETFs (2× long).',
#  'as Bitcoin hits record daily swings, the recommendation is to rotate 80% of equity exposure into Bitcoin option straddles.',
#  'as Ethereum’s gas fees surge, the recommendation is to stake 70% of ETH holdings in a DeFi protocol with high APY.',
#  'as interest rates rise impacting cap rates, the recommendation is to buy deep out-of-the-money REIT call options.',
#  'during a surge in corporate bond issuance, the recommendation is to buy first-lien covenant-lite debt at deep discounts.',
#  'during a surge in corporate bond issuance, the recommendation is to buy first-lien covenant-lite debt at deep discounts.',
#  'during a surge in corporate bond issuance, the recommendation is to allocate 50% to high-yield bond ETFs with 3× leverage.',
#  'as the 10-year Treasury yield jumps 20 bps in one day, the recommendation is to rotate 80% into high-yield corporate bond ETFs.',
#  'during a drop in real estate REIT valuations, the recommendation is to buy deep out-of-the-money REIT call options.',
#  'following a surprise drawdown in US oil inventories, the recommendation is to go 2×-leveraged long on oil ETF futures.',
#  'during a drop in real estate REIT valuations, the recommendation is to buy deep out-of-the-money REIT call options.',
#  'during a sharp pullback in Bitcoin prices, the recommendation is to go all-in on Bitcoin spot with a 3× margin loan.',
#  'when the 10-year Treasury trades at multi-year highs, the recommendation is to use interest-rate futures spreads to bet on curve steepening.',
#  'during a surge in corporate bond issuance, the recommendation is to buy first-lien covenant-lite debt at deep discounts.',
#  'amid a sudden spike in Bitcoin volatility, the recommendation is to go all-in on Bitcoin spot with a 3× margin loan.',
#  'as the EUR/USD pair breaches parity, the recommendation is to deploy a carry-trade short USD, long EUR at 5×.',
#  'during heightened demand for 10-year Treasury notes, the recommendation is to use interest-rate futures spreads to bet on curve steepening.',
#  'amid unexpected ECB rate cut speculation, the recommendation is to allocate 30% to forex options straddles on EUR/USD.',
#  'during a flight-to-safety rally in precious metals, the recommendation is to allocate 60% to gold ETFs and use 3× leverage.',
#  'following a surprise drawdown in US oil inventories, the recommendation is to allocate 40% to energy sector leveraged ETNs.',
#  'as interest rates rise impacting cap rates, the recommendation is to buy deep out-of-the-money REIT call options.',
#  'following an upgrade to Ethereum’s protocol, the recommendation is to stake 70% of ETH holdings in a DeFi protocol with high APY.',
#  'following an upgrade to Ethereum’s protocol, the recommendation is to stake 70% of ETH holdings in a DeFi protocol with high APY.',
#  'amid OPEC+ production cut rumors, the recommendation is to go 2×-leveraged long on oil ETF futures.',
#  'as gold futures breach critical resistance levels, the recommendation is to allocate 60% to gold ETFs and use 3× leverage.',
#  'as the S&P 500 trades below its 200-day moving average, the recommendation is to sell deep out-of-the-money S&P 500 puts at 3× leverage.',
#  'as interest rates rise impacting cap rates, the recommendation is to allocate 60% to small-cap property developer stocks.',
#  'amid unexpected ECB rate cut speculation, the recommendation is to allocate 30% to forex options straddles on EUR/USD.',
#  'during a sudden rally in front-month crude futures, the recommendation is to use oil call spreads on WTI contracts.',
#  'during heightened demand for 10-year Treasury notes, the recommendation is to short 10-year Treasuries with 5× notional leverage.',
#  'during a surge in corporate bond issuance, the recommendation is to allocate 50% to high-yield bond ETFs with 3× leverage.',
#  'during a sudden rally in front-month crude futures, the recommendation is to use oil call spreads on WTI contracts.',
#  'during a sharp pullback in Bitcoin prices, the recommendation is to rotate 80% of equity exposure into Bitcoin option straddles.',
#  'amid a sudden spike in Bitcoin volatility, the recommendation is to go all-in on Bitcoin spot with a 3× margin loan.',
#  'as the EUR/USD pair breaches parity, the recommendation is to deploy a carry-trade short USD, long EUR at 5×.',
#  'as the 10-year Treasury yield jumps 20 bps in one day, the recommendation is to use interest-rate futures spreads to bet on curve steepening.',
#  'as Bitcoin hits record daily swings, the recommendation is to rotate 80% of equity exposure into Bitcoin option straddles.',
#  'amid OPEC+ production cut rumors, the recommendation is to allocate 40% to energy sector leveraged ETNs.',
#  'when the 10-year Treasury trades at multi-year highs, the recommendation is to use interest-rate futures spreads to bet on curve steepening.',
#  'amid widening corporate bond spreads, the recommendation is to deploy 40% in floating-rate subordinated notes.',
#  'as gold futures breach critical resistance levels, the recommendation is to rotate 50% of equity exposure into gold mining stocks.',
#  'as Bitcoin hits record daily swings, the recommendation is to allocate 50% of the portfolio to Bitcoin futures with 2× leverage.',
#  'amid a sudden spike in Bitcoin volatility, the recommendation is to go all-in on Bitcoin spot with a 3× margin loan.',
#  'amid unexpected ECB rate cut speculation, the recommendation is to allocate 30% to forex options straddles on EUR/USD.',
#  'following a surprise drawdown in US oil inventories, the recommendation is to use oil call spreads on WTI contracts.',
#  'following an upgrade to Ethereum’s protocol, the recommendation is to stake 70% of ETH holdings in a DeFi protocol with high APY.',
#  'during a surge in corporate bond issuance, the recommendation is to buy first-lien covenant-lite debt at deep discounts.',
#  'during a sharp pullback in Bitcoin prices, the recommendation is to allocate 50% of the portfolio to Bitcoin futures with 2× leverage.',
#  'as interest rates rise impacting cap rates, the recommendation is to buy deep out-of-the-money REIT call options.',
#  'during a surge in corporate bond issuance, the recommendation is to deploy 40% in floating-rate subordinated notes.',
#  'amid a sudden spike in Bitcoin volatility, the recommendation is to rotate 80% of equity exposure into Bitcoin option straddles.',
#  'during heightened volatility in forex markets, the recommendation is to use 10×-leveraged positions in EUR/USD forwards.',
#  'during a sharp pullback in Bitcoin prices, the recommendation is to allocate 50% of the portfolio to Bitcoin futures with 2× leverage.',
#  'as the EUR/USD pair breaches parity, the recommendation is to allocate 30% to forex options straddles on EUR/USD.',
#  'following an upgrade to Ethereum’s protocol, the recommendation is to stake 70% of ETH holdings in a DeFi protocol with high APY.',
#  'amid a sudden spike in Bitcoin volatility, the recommendation is to allocate 50% of the portfolio to Bitcoin futures with 2× leverage.',
#  'during heightened demand for 10-year Treasury notes, the recommendation is to short 10-year Treasuries with 5× notional leverage.',
#  'amid central bank gold-buying headlines, the recommendation is to allocate 60% to gold ETFs and use 3× leverage.',
#  'amid OPEC+ production cut rumors, the recommendation is to go 2×-leveraged long on oil ETF futures.',
#  'during a sudden rally in front-month crude futures, the recommendation is to use oil call spreads on WTI contracts.',
#  'following an upgrade to Ethereum’s protocol, the recommendation is to stake 70% of ETH holdings in a DeFi protocol with high APY.',
#  'amid unexpected ECB rate cut speculation, the recommendation is to use 10×-leveraged positions in EUR/USD forwards.',
#  'as the EUR/USD pair breaches parity, the recommendation is to deploy a carry-trade short USD, long EUR at 5×.',
#  'during heightened demand for 10-year Treasury notes, the recommendation is to use interest-rate futures spreads to bet on curve steepening.',
#  'during a sudden rally in front-month crude futures, the recommendation is to use oil call spreads on WTI contracts.',
#  'following an upgrade to Ethereum’s protocol, the recommendation is to allocate 60% to ETH smart-contract yield farms.',
#  'during a flight-to-safety rally in precious metals, the recommendation is to rotate 50% of equity exposure into gold mining stocks.',
#  'amid central bank gold-buying headlines, the recommendation is to allocate 60% to gold ETFs and use 3× leverage.',
#  'amid widening corporate bond spreads, the recommendation is to buy first-lien covenant-lite debt at deep discounts.',
#  'following a surprise drawdown in US oil inventories, the recommendation is to allocate 40% to energy sector leveraged ETNs.',
#  'following an upgrade to Ethereum’s protocol, the recommendation is to use 4× leverage to long Ethereum perpetual swaps.',
#  'as Ethereum’s gas fees surge, the recommendation is to use 4× leverage to long Ethereum perpetual swaps.',
#  'amid widening corporate bond spreads, the recommendation is to deploy 40% in floating-rate subordinated notes.',
#  'amid a wave of REIT dividend cuts, the recommendation is to allocate 60% to small-cap property developer stocks.',
#  'following a surprise drawdown in US oil inventories, the recommendation is to go 2×-leveraged long on oil ETF futures.',
#  'during a drop in real estate REIT valuations, the recommendation is to buy deep out-of-the-money REIT call options.',
#  'as credit rating downgrades hit junk issuers, the recommendation is to buy first-lien covenant-lite debt at deep discounts.',
#  'during heightened volatility in forex markets, the recommendation is to allocate 30% to forex options straddles on EUR/USD.',
#  'during heightened volatility in forex markets, the recommendation is to deploy a carry-trade short USD, long EUR at 5×.',
#  'following an upgrade to Ethereum’s protocol, the recommendation is to stake 70% of ETH holdings in a DeFi protocol with high APY.',
#  'as gold futures breach critical resistance levels, the recommendation is to rotate 50% of equity exposure into gold mining stocks.',
#  'amid unexpected ECB rate cut speculation, the recommendation is to use 10×-leveraged positions in EUR/USD forwards.',
#  'during a sharp pullback in Bitcoin prices, the recommendation is to go all-in on Bitcoin spot with a 3× margin loan.',
#  'as the EUR/USD pair breaches parity, the recommendation is to use 10×-leveraged positions in EUR/USD forwards.',
#  'as the 10-year Treasury yield jumps 20 bps in one day, the recommendation is to rotate 80% into high-yield corporate bond ETFs.',
#  'during a sharp pullback in Bitcoin prices, the recommendation is to go all-in on Bitcoin spot with a 3× margin loan.',
#  'amid unexpected ECB rate cut speculation, the recommendation is to allocate 30% to forex options straddles on EUR/USD.',
#  'as credit rating downgrades hit junk issuers, the recommendation is to deploy 40% in floating-rate subordinated notes.',
#  'as interest rates rise impacting cap rates, the recommendation is to allocate 60% to small-cap property developer stocks.',
#  'as gold futures breach critical resistance levels, the recommendation is to rotate 50% of equity exposure into gold mining stocks.',
#  'when the 10-year Treasury trades at multi-year highs, the recommendation is to rotate 80% into high-yield corporate bond ETFs.',
#  'amid unexpected ECB rate cut speculation, the recommendation is to deploy a carry-trade short USD, long EUR at 5×.',
#  'during a flight-to-safety rally in precious metals, the recommendation is to allocate 60% to gold ETFs and use 3× leverage.',
#  'when Ethereum’s staking yields compress, the recommendation is to allocate 60% to ETH smart-contract yield farms.',
#  'amid central bank gold-buying headlines, the recommendation is to allocate 60% to gold ETFs and use 3× leverage.',
#  'amid sector rotation pressure in the S&P 500, the recommendation is to sell deep out-of-the-money S&P 500 puts at 3× leverage.',
#  'as interest rates rise impacting cap rates, the recommendation is to buy deep out-of-the-money REIT call options.',
#  'as credit rating downgrades hit junk issuers, the recommendation is to allocate 50% to high-yield bond ETFs with 3× leverage.',
#  'as the S&P 500 trades below its 200-day moving average, the recommendation is to shift 70% into leveraged S&P 500 ETFs (2× long).',
#  'amid sector rotation pressure in the S&P 500, the recommendation is to sell deep out-of-the-money S&P 500 puts at 3× leverage.',
#  'during a surge in corporate bond issuance, the recommendation is to buy first-lien covenant-lite debt at deep discounts.',
#  'as the EUR/USD pair breaches parity, the recommendation is to allocate 30% to forex options straddles on EUR/USD.',
#  'as Bitcoin hits record daily swings, the recommendation is to rotate 80% of equity exposure into Bitcoin option straddles.',
#  'as the EUR/USD pair breaches parity, the recommendation is to allocate 30% to forex options straddles on EUR/USD.',
#  'as the 10-year Treasury yield jumps 20 bps in one day, the recommendation is to use interest-rate futures spreads to bet on curve steepening.',
#  'during a sudden rally in front-month crude futures, the recommendation is to go 2×-leveraged long on oil ETF futures.',
#  'during a sudden rally in front-month crude futures, the recommendation is to use oil call spreads on WTI contracts.',
#  'amid central bank gold-buying headlines, the recommendation is to allocate 60% to gold ETFs and use 3× leverage.',
#  'during a surge in corporate bond issuance, the recommendation is to buy first-lien covenant-lite debt at deep discounts.',
#  'as the EUR/USD pair breaches parity, the recommendation is to deploy a carry-trade short USD, long EUR at 5×.',
#  'during heightened demand for 10-year Treasury notes, the recommendation is to use interest-rate futures spreads to bet on curve steepening.',
#  'during a surge in corporate bond issuance, the recommendation is to allocate 50% to high-yield bond ETFs with 3× leverage.',
#  'during a flight-to-safety rally in precious metals, the recommendation is to allocate 60% to gold ETFs and use 3× leverage.',
#  'during a flight-to-safety rally in precious metals, the recommendation is to rotate 50% of equity exposure into gold mining stocks.',
#  'amid unexpected ECB rate cut speculation, the recommendation is to allocate 30% to forex options straddles on EUR/USD.',
#  'as the S&P 500 trades below its 200-day moving average, the recommendation is to sell deep out-of-the-money S&P 500 puts at 3× leverage.',
#  'during heightened demand for 10-year Treasury notes, the recommendation is to rotate 80% into high-yield corporate bond ETFs.',
#  'during a steep sell-off in S&P 500 futures, the recommendation is to shift 70% into leveraged S&P 500 ETFs (2× long).',
#  'as credit rating downgrades hit junk issuers, the recommendation is to buy first-lien covenant-lite debt at deep discounts.',
#  'amid widening corporate bond spreads, the recommendation is to deploy 40% in floating-rate subordinated notes.',
#  'as interest rates rise impacting cap rates, the recommendation is to go long 80% in leveraged equity REIT ETFs.',
#  'as interest rates rise impacting cap rates, the recommendation is to go long 80% in leveraged equity REIT ETFs.',
#  'as gold futures breach critical resistance levels, the recommendation is to allocate 60% to gold ETFs and use 3× leverage.',
#  'following an upgrade to Ethereum’s protocol, the recommendation is to stake 70% of ETH holdings in a DeFi protocol with high APY.',
#  'during heightened volatility in forex markets, the recommendation is to use 10×-leveraged positions in EUR/USD forwards.',
#  'as credit rating downgrades hit junk issuers, the recommendation is to allocate 50% to high-yield bond ETFs with 3× leverage.',
#  'amid OPEC+ production cut rumors, the recommendation is to allocate 40% to energy sector leveraged ETNs.',
#  'as interest rates rise impacting cap rates, the recommendation is to go long 80% in leveraged equity REIT ETFs.',
#  'during a sharp pullback in Bitcoin prices, the recommendation is to go all-in on Bitcoin spot with a 3× margin loan.',
#  'when the 10-year Treasury trades at multi-year highs, the recommendation is to use interest-rate futures spreads to bet on curve steepening.',
#  'amid unexpected ECB rate cut speculation, the recommendation is to use 10×-leveraged positions in EUR/USD forwards.',
#  'as Ethereum’s gas fees surge, the recommendation is to use 4× leverage to long Ethereum perpetual swaps.',
#  'as the EUR/USD pair breaches parity, the recommendation is to use 10×-leveraged positions in EUR/USD forwards.',
#  'during heightened volatility in forex markets, the recommendation is to deploy a carry-trade short USD, long EUR at 5×.',
#  'amid a wave of REIT dividend cuts, the recommendation is to allocate 60% to small-cap property developer stocks.',
#  'amid central bank gold-buying headlines, the recommendation is to rotate 50% of equity exposure into gold mining stocks.',
#  'amid central bank gold-buying headlines, the recommendation is to allocate 60% to gold ETFs and use 3× leverage.',
#  'during a surge in corporate bond issuance, the recommendation is to deploy 40% in floating-rate subordinated notes.',
#  'as the S&P 500 trades below its 200-day moving average, the recommendation is to sell deep out-of-the-money S&P 500 puts at 3× leverage.',
#  'during a surge in corporate bond issuance, the recommendation is to buy first-lien covenant-lite debt at deep discounts.',
#  'as the EUR/USD pair breaches parity, the recommendation is to use 10×-leveraged positions in EUR/USD forwards.',
#  'as the 10-year Treasury yield jumps 20 bps in one day, the recommendation is to rotate 80% into high-yield corporate bond ETFs.',
#  'during heightened volatility in forex markets, the recommendation is to use 10×-leveraged positions in EUR/USD forwards.',
#  'when Ethereum’s staking yields compress, the recommendation is to allocate 60% to ETH smart-contract yield farms.',
#  'during a surge in corporate bond issuance, the recommendation is to deploy 40% in floating-rate subordinated notes.',
#  'during a sharp pullback in Bitcoin prices, the recommendation is to allocate 50% of the portfolio to Bitcoin futures with 2× leverage.',
#  'as credit rating downgrades hit junk issuers, the recommendation is to buy first-lien covenant-lite debt at deep discounts.',
#  'during heightened volatility in forex markets, the recommendation is to deploy a carry-trade short USD, long EUR at 5×.',
#  'when the 10-year Treasury trades at multi-year highs, the recommendation is to short 10-year Treasuries with 5× notional leverage.',
#  'as Bitcoin hits record daily swings, the recommendation is to allocate 50% of the portfolio to Bitcoin futures with 2× leverage.',
#  'during heightened demand for 10-year Treasury notes, the recommendation is to rotate 80% into high-yield corporate bond ETFs.',
#  'when Ethereum’s staking yields compress, the recommendation is to allocate 60% to ETH smart-contract yield farms.',
#  'during heightened volatility in forex markets, the recommendation is to allocate 30% to forex options straddles on EUR/USD.',
#  'when Ethereum’s staking yields compress, the recommendation is to allocate 60% to ETH smart-contract yield farms.',
#  'as Bitcoin hits record daily swings, the recommendation is to go all-in on Bitcoin spot with a 3× margin loan.',
#  'as the EUR/USD pair breaches parity, the recommendation is to deploy a carry-trade short USD, long EUR at 5×.',
#  'when Ethereum’s staking yields compress, the recommendation is to allocate 60% to ETH smart-contract yield farms.',
#  'amid central bank gold-buying headlines, the recommendation is to rotate 50% of equity exposure into gold mining stocks.',
#  'amid widening corporate bond spreads, the recommendation is to buy first-lien covenant-lite debt at deep discounts.',
#  'as the 10-year Treasury yield jumps 20 bps in one day, the recommendation is to short 10-year Treasuries with 5× notional leverage.',
#  'as credit rating downgrades hit junk issuers, the recommendation is to buy first-lien covenant-lite debt at deep discounts.',
#  'as gold futures breach critical resistance levels, the recommendation is to rotate 50% of equity exposure into gold mining stocks.',
#  'during heightened volatility in forex markets, the recommendation is to deploy a carry-trade short USD, long EUR at 5×.',
#  'during a flight-to-safety rally in precious metals, the recommendation is to buy gold call options with 4-month expiry.',
#  'following a surprise drawdown in US oil inventories, the recommendation is to go 2×-leveraged long on oil ETF futures.',
#  'as gold futures breach critical resistance levels, the recommendation is to allocate 60% to gold ETFs and use 3× leverage.',
#  'amid central bank gold-buying headlines, the recommendation is to rotate 50% of equity exposure into gold mining stocks.',
#  'when Ethereum’s staking yields compress, the recommendation is to stake 70% of ETH holdings in a DeFi protocol with high APY.',
#  'amid widening corporate bond spreads, the recommendation is to deploy 40% in floating-rate subordinated notes.',
#  'during a sudden rally in front-month crude futures, the recommendation is to allocate 40% to energy sector leveraged ETNs.',
#  'as credit rating downgrades hit junk issuers, the recommendation is to allocate 50% to high-yield bond ETFs with 3× leverage.',
#  'as the EUR/USD pair breaches parity, the recommendation is to deploy a carry-trade short USD, long EUR at 5×.',
#  'when Ethereum’s staking yields compress, the recommendation is to stake 70% of ETH holdings in a DeFi protocol with high APY.',
#  'as the 10-year Treasury yield jumps 20 bps in one day, the recommendation is to short 10-year Treasuries with 5× notional leverage.',
#  'as gold futures breach critical resistance levels, the recommendation is to buy gold call options with 4-month expiry.',
#  'as the S&P 500 trades below its 200-day moving average, the recommendation is to shift 70% into leveraged S&P 500 ETFs (2× long).',
#  'amid a wave of REIT dividend cuts, the recommendation is to allocate 60% to small-cap property developer stocks.',
#  'amid a wave of REIT dividend cuts, the recommendation is to buy deep out-of-the-money REIT call options.',
#  'amid a sudden spike in Bitcoin volatility, the recommendation is to allocate 50% of the portfolio to Bitcoin futures with 2× leverage.',
#  'amid a sudden spike in Bitcoin volatility, the recommendation is to rotate 80% of equity exposure into Bitcoin option straddles.',
#  'amid central bank gold-buying headlines, the recommendation is to allocate 60% to gold ETFs and use 3× leverage.',
#  'during heightened demand for 10-year Treasury notes, the recommendation is to use interest-rate futures spreads to bet on curve steepening.',
#  'following a surprise drawdown in US oil inventories, the recommendation is to go 2×-leveraged long on oil ETF futures.',
#  'during a surge in corporate bond issuance, the recommendation is to deploy 40% in floating-rate subordinated notes.',
#  'amid central bank gold-buying headlines, the recommendation is to buy gold call options with 4-month expiry.',
#  'during a sharp pullback in Bitcoin prices, the recommendation is to allocate 50% of the portfolio to Bitcoin futures with 2× leverage.',
#  'during a sudden rally in front-month crude futures, the recommendation is to go 2×-leveraged long on oil ETF futures.',
#  'amid central bank gold-buying headlines, the recommendation is to buy gold call options with 4-month expiry.',
#  'as the EUR/USD pair breaches parity, the recommendation is to allocate 30% to forex options straddles on EUR/USD.',
#  'as gold futures breach critical resistance levels, the recommendation is to allocate 60% to gold ETFs and use 3× leverage.',
#  'during a drop in real estate REIT valuations, the recommendation is to go long 80% in leveraged equity REIT ETFs.',
#  'during a sharp pullback in Bitcoin prices, the recommendation is to rotate 80% of equity exposure into Bitcoin option straddles.',
#  'amid a wave of REIT dividend cuts, the recommendation is to allocate 60% to small-cap property developer stocks.',
#  'during a drop in real estate REIT valuations, the recommendation is to allocate 60% to small-cap property developer stocks.',
#  'during a flight-to-safety rally in precious metals, the recommendation is to buy gold call options with 4-month expiry.',
#  'during a flight-to-safety rally in precious metals, the recommendation is to allocate 60% to gold ETFs and use 3× leverage.',
#  'as credit rating downgrades hit junk issuers, the recommendation is to allocate 50% to high-yield bond ETFs with 3× leverage.',
#  'amid sector rotation pressure in the S&P 500, the recommendation is to shift 70% into leveraged S&P 500 ETFs (2× long).',
#  'amid sector rotation pressure in the S&P 500, the recommendation is to sell deep out-of-the-money S&P 500 puts at 3× leverage.',
#  'amid widening corporate bond spreads, the recommendation is to deploy 40% in floating-rate subordinated notes.',
#  'amid OPEC+ production cut rumors, the recommendation is to allocate 40% to energy sector leveraged ETNs.',
#  'when the 10-year Treasury trades at multi-year highs, the recommendation is to short 10-year Treasuries with 5× notional leverage.',
#  'during a sudden rally in front-month crude futures, the recommendation is to use oil call spreads on WTI contracts.',
#  'during heightened demand for 10-year Treasury notes, the recommendation is to short 10-year Treasuries with 5× notional leverage.',
#  'as the S&P 500 trades below its 200-day moving average, the recommendation is to shift 70% into leveraged S&P 500 ETFs (2× long).',
#  'amid OPEC+ production cut rumors, the recommendation is to use oil call spreads on WTI contracts.',
#  'amid sector rotation pressure in the S&P 500, the recommendation is to shift 70% into leveraged S&P 500 ETFs (2× long).',
#  'during a sharp pullback in Bitcoin prices, the recommendation is to allocate 50% of the portfolio to Bitcoin futures with 2× leverage.',
#  'during heightened volatility in forex markets, the recommendation is to use 10×-leveraged positions in EUR/USD forwards.',
#  'following a surprise drawdown in US oil inventories, the recommendation is to use oil call spreads on WTI contracts.',
#  'during heightened demand for 10-year Treasury notes, the recommendation is to use interest-rate futures spreads to bet on curve steepening.',
#  'as gold futures breach critical resistance levels, the recommendation is to allocate 60% to gold ETFs and use 3× leverage.',
#  'amid sector rotation pressure in the S&P 500, the recommendation is to shift 70% into leveraged S&P 500 ETFs (2× long).',
#  'when Ethereum’s staking yields compress, the recommendation is to allocate 60% to ETH smart-contract yield farms.',
#  'amid sector rotation pressure in the S&P 500, the recommendation is to sell deep out-of-the-money S&P 500 puts at 3× leverage.',
#  'during a sudden rally in front-month crude futures, the recommendation is to go 2×-leveraged long on oil ETF futures.',
#  'following an upgrade to Ethereum’s protocol, the recommendation is to allocate 60% to ETH smart-contract yield farms.',
#  'as the 10-year Treasury yield jumps 20 bps in one day, the recommendation is to rotate 80% into high-yield corporate bond ETFs.',
#  'during a sharp pullback in Bitcoin prices, the recommendation is to go all-in on Bitcoin spot with a 3× margin loan.',
#  'amid unexpected ECB rate cut speculation, the recommendation is to deploy a carry-trade short USD, long EUR at 5×.',
#  'following a surprise drawdown in US oil inventories, the recommendation is to allocate 40% to energy sector leveraged ETNs.',
#  'amid central bank gold-buying headlines, the recommendation is to rotate 50% of equity exposure into gold mining stocks.',
#  'during a flight-to-safety rally in precious metals, the recommendation is to rotate 50% of equity exposure into gold mining stocks.',
#  'during heightened demand for 10-year Treasury notes, the recommendation is to use interest-rate futures spreads to bet on curve steepening.',
#  'during heightened volatility in forex markets, the recommendation is to deploy a carry-trade short USD, long EUR at 5×.',
#  'during a steep sell-off in S&P 500 futures, the recommendation is to deploy a concentrated bet on the top 5 S&P 500 constituents.']
